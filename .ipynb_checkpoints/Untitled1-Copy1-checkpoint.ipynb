# %%
# %%



# %%

# %% [markdown]
# ### Handling missing data

# %%
#Categorizing the columns with missing values into numerical and categorical
col_cat = df_new.select_dtypes(include=['object'])
col_num = df_new.select_dtypes(include=['float64'])
#Checking sets of categorical columns with missing values
df_null = list(col_cat.columns[col_cat.isnull().any()==True])
df_null

# %%
#Checking sets of numerical columns with missing values
df_null = list(col_num.columns[col_num.isnull().any()==True])
df_null

# %%
#Which column has most of their values missing
df_new.columns[df_new.isnull().mean() >= 0.5]

# %%
df_new.isnull().mean()

# %%
df_new = df.iloc[:,np.r_[0,1,2,3,5,6,7,8,9,10,11,12,19:37,39:43,58]]
#df_new['DevType'].value_counts()
df_new['DevType'] = df_new['DevType'].str.split(pat=';', n=-1, expand=False)
poss_values =[]
for row in df_new['DevType']:
    poss_values.append(row)
poss_values
    
    

# %%

#df_new.drop(df_new[df_new['DevType']=='nan'])
df_new.isnull().any()


# %%
df_new[df_new['DevType']==' ']

# %%

            
                

# %%
from ast import literal_eval
df_new['DevType']=df_new['DevType'].str.split(';')
df_new['DevType'] =df_new['DevType'].replace("nan", "None").apply(literal_eval) #convert to list type

# %%
#Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#read in the data and
df = pd.read_csv('survey_results_public.csv')

df.shape

#Extracting the columns we need
df_new = df.iloc[:,np.r_[0,1,2,3,5,6,7,8,9,10,11,12,19:37,39:43,58]].reset_index(drop=True)

# %%
df_new.dropna(subset =['DevType'],inplace=True)
df_new=df_new.reset_index(drop=True)
#df_new.dtypes

# %%
a=set()
#f=df_new['DevType'].str.split(';')
for row in f:
    
    for role in row:
        a.add(role)
        
a
# Out:
# {'Academic researcher',
#  'Blockchain',
#  'Cloud infrastructure engineer',
#  'Data or business analyst',
#  'Data scientist or machine learning specialist',
#  'Database administrator',
#  'Designer',
#  'DevOps specialist',
#  'Developer, QA or test',
#  'Developer, back-end',
#  'Developer, desktop or enterprise applications',
#  'Developer, embedded applications or devices',
#  'Developer, front-end',
#  'Developer, full-stack',
#  'Developer, game or graphics',
#  'Developer, mobile',
#  'Educator',
#  'Engineer, data',
#  'Engineer, site reliability',
#  'Engineering manager',
#  'Marketing or sales professional',
#  'Other (please specify):',
#  'Product manager',
#  'Project manager',
#  'Scientist',
#  'Security professional',
#  'Senior Executive (C-Suite, VP, etc.)',
#  'Student',
#  'System administrator'}

# %%
for row in f:
            for role in row:
                print(cell)

# %%
df_new['DevType']=df_new['DevType'].str.split(';')
df_new['DevType']
# Out:
# 0        [Data scientist or machine learning specialist...
# 1                                  [Developer, full-stack]
# 2        [Developer, front-end, Developer, full-stack, ...
# 3                         [Developer, full-stack, Student]
# 4                                    [Developer, back-end]
#                                ...
# 61297                                [Developer, back-end]
# 61298      [Data scientist or machine learning specialist]
# 61299    [Developer, full-stack, Developer, desktop or ...
# 61300    [Developer, front-end, Developer, desktop or e...
# 61301    [Developer, front-end, Engineer, data, Enginee...
# Name: DevType, Length: 61302, dtype: object

# %%
from collections import defaultdict
new_df=defaultdict(int)
for val in a:
    for idx in range(df_new.shape[0]):
        for row in df_new['DevType'][idx]:
            if val in df_new['DevType'][idx]: 
                df_new['DevType']=val
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12208/2323027308.py in <module>
#       5         for row in df_new['DevType'][idx]:
#       6             if val in df_new['DevType'][idx]:
# ----> 7                 df_new['DevType']=val
#       8
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3795                     value = np.tile(value, (len(existing_piece.columns), 1)).T
#    3796
# -> 3797         self._set_item_mgr(key, value)
#    3798
#    3799     def _set_value(
#
# ...

# %%
df_new['DevType'][10]
# Out:
# ['Developer, full-stack', 'Academic researcher', 'DevOps specialist']

# %%
list(a)
# Out:
# {'Academic researcher',
#  'Blockchain',
#  'Cloud infrastructure engineer',
#  'Data or business analyst',
#  'Data scientist or machine learning specialist',
#  'Database administrator',
#  'Designer',
#  'DevOps specialist',
#  'Developer, QA or test',
#  'Developer, back-end',
#  'Developer, desktop or enterprise applications',
#  'Developer, embedded applications or devices',
#  'Developer, front-end',
#  'Developer, full-stack',
#  'Developer, game or graphics',
#  'Developer, mobile',
#  'Educator',
#  'Engineer, data',
#  'Engineer, site reliability',
#  'Engineering manager',
#  'Marketing or sales professional',
#  'Other (please specify):',
#  'Product manager',
#  'Project manager',
#  'Scientist',
#  'Security professional',
#  'Senior Executive (C-Suite, VP, etc.)',
#  'Student',
#  'System administrator'}

# %%
#Udacity method
career=df_new['DevType'].value_counts().reset_index()
career.rename(columns = {'index':'role','DevType':'count'},inplace=True)
from collections import defaultdict
new_df=defaultdict(int)
for val in sorted(a):
    for idx in range(career.shape[0]):
        for row in career['role'][idx]:
            if val in career['role'][idx]: 
                new_df['role']+=int(career['count'][idx])
                
                
new_df=pd.DataFrame(pd.Series(new_df)).reset_index()
new_df

# %%
df1 = pd.DataFrame(df['DevType'].dropna().str.split(';').tolist()).stack()

# %%
df1.reset_index(drop=True)
# Out:
# 0         Data scientist or machine learning specialist
# 1                                  Developer, front-end
# 2                                        Engineer, data
# 3                            Engineer, site reliability
# 4                                 Developer, full-stack
#                               ...
# 164785                         Data or business analyst
# 164786                                         Designer
# 164787                                        Scientist
# 164788                                  Product manager
# 164789                             System administrator
# Length: 164790, dtype: object

# %%
df_new['DevType']
# Out:
# 0        [Data scientist or machine learning specialist...
# 1                                  [Developer, full-stack]
# 2        [Developer, front-end, Developer, full-stack, ...
# 3                         [Developer, full-stack, Student]
# 4                                    [Developer, back-end]
#                                ...
# 61297                                [Developer, back-end]
# 61298      [Data scientist or machine learning specialist]
# 61299    [Developer, full-stack, Developer, desktop or ...
# 61300    [Developer, front-end, Developer, desktop or e...
# 61301    [Developer, front-end, Engineer, data, Enginee...
# Name: DevType, Length: 61302, dtype: object

# %%
df_new.DevType.apply(pd.Series)
# Out:
#                                                   0   \
# 0      Data scientist or machine learning specialist
# 1                              Developer, full-stack
# 2                               Developer, front-end
# 3                              Developer, full-stack
# 4                                Developer, back-end
# ...                                              ...
# 61297                            Developer, back-end
# 61298  Data scientist or machine learning specialist
# 61299                          Developer, full-stack
# 61300                           Developer, front-end
# 61301                           Developer, front-end
#
#                                                   1   \
# 0                               Developer, front-end
# 1                                                NaN
# 2                              Developer, full-stack
# 3                                            Student
# 4                                                NaN
# ...

# %%
df_new.DevType.apply(pd.Series) \
    .merge(df_new, right_index = True, left_index = True)
# Out:
#                                                    0  \
# 0      Data scientist or machine learning specialist
# 1                              Developer, full-stack
# 2                               Developer, front-end
# 3                              Developer, full-stack
# 4                                Developer, back-end
# ...                                              ...
# 61297                            Developer, back-end
# 61298  Data scientist or machine learning specialist
# 61299                          Developer, full-stack
# 61300                           Developer, front-end
# 61301                           Developer, front-end
#
#                                                    1  \
# 0                               Developer, front-end
# 1                                                NaN
# 2                              Developer, full-stack
# 3                                            Student
# 4                                                NaN
# ...

# %%
w=df_new.DevType.apply(pd.Series) \
   .merge(df_new, right_index = True, left_index = True) \
   .drop(["DevType"], axis = 1) \
   .melt(id_vars = df.iloc[:,np.r_[0,1,2,3,5,6,7,8,9,10,12,19:37,39:43,58]], value_name = "DevType")

# %%
w.head(10)
# Out:
#    ResponseId                                         MainBranch  \
# 0           3  I am not primarily a developer, but I write co...
# 1           4                     I am a developer by profession
# 2           5                     I am a developer by profession
# 3           8                     I am a developer by profession
# 4           9                     I am a developer by profession
# 5          10                     I am a developer by profession
# 6          11                     I am a developer by profession
# 7          12  I am not primarily a developer, but I write co...
# 8          13                     I am a developer by profession
# 9          14                     I am a developer by profession
#
#                                           Employment  \
# 0                                Employed, full-time
# 1                                Employed, full-time
# 2                                Employed, full-time
# ...

# %%
df_new.DevType[2]
# Out:
# ['Developer, front-end',
#  'Developer, full-stack',
#  'Developer, back-end',
#  'Developer, desktop or enterprise applications',
#  'Developer, QA or test']

# %%
w[w.ResponseId==5]
# Out:
#         ResponseId                      MainBranch           Employment  \
# 2                5  I am a developer by profession  Employed, full-time
# 61304            5  I am a developer by profession  Employed, full-time
# 122606           5  I am a developer by profession  Employed, full-time
# 183908           5  I am a developer by profession  Employed, full-time
# 245210           5  I am a developer by profession  Employed, full-time
#
#                                   RemoteWork  \
# 2       Hybrid (some remote, some in-person)
# 61304   Hybrid (some remote, some in-person)
# 122606  Hybrid (some remote, some in-person)
# 183908  Hybrid (some remote, some in-person)
# 245210  Hybrid (some remote, some in-person)
#
#                                              EdLevel  \
# 2       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 61304   Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 122606  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %%
w=, index=df.idw.drop("variable", axis=1) \
    .dropna(subset=['DevType'])

# %%
#method2
df_stack = pd.DataFrame(df_new.DevType.str.split(",").to_list(), index=df_new.iloc[:,np.r_[0,1,2,3,5]]).stack()
df_stack = df_stack.reset_index()
#df_stack.columns = ["id","nanes","names","jj","gg","hh"]
  
print(df_stack)
# Out:
#                                                   level_0  level_1  \
# 0       (3, I am not primarily a developer, but I writ...        0
# 1       (3, I am not primarily a developer, but I writ...        1
# 2       (3, I am not primarily a developer, but I writ...        2
# 3       (3, I am not primarily a developer, but I writ...        3
# 4       (4, I am a developer by profession, Employed, ...        0
# ...                                                   ...      ...
# 167701  (73268, I used to be a developer by profession...        6
# 167702  (73268, I used to be a developer by profession...        7
# 167703  (73268, I used to be a developer by profession...        8
# 167704  (73268, I used to be a developer by profession...        9
# 167705  (73268, I used to be a developer by profession...       10
#
#                                                         0
# 0       Data scientist or machine learning specialist;...
# ...

# %%
df_new.DevType.str.split(";").to_list()
# Out:
# [['Data scientist or machine learning specialist',
#   'Developer, front-end',
#   'Engineer, data',
#   'Engineer, site reliability'],
#  ['Developer, full-stack'],
#  ['Developer, front-end',
#   'Developer, full-stack',
#   'Developer, back-end',
#   'Developer, desktop or enterprise applications',
#   'Developer, QA or test'],
#  ['Developer, full-stack', 'Student'],
#  ['Developer, back-end'],
#  ['Developer, desktop or enterprise applications',
#   'Developer, mobile',
#   'Educator'],
#  ['Developer, full-stack', 'Developer, back-end'],
#  ['Engineering manager'],
#  ['Developer, full-stack'],
#  ['Developer, front-end',
#   'Developer, full-stack',
#   'Developer, back-end',
#   'Database administrator'],
#  ['Developer, full-stack', 'Academic researcher', 'DevOps specialist'],
#  ['Developer, full-stack'],
#  ['Developer, full-stack'],
#  ['Engineer, data'],
#  ['Developer, back-end', 'Developer, desktop or enterprise applications'],
#  ['Student'],
# ...

# %%
a=df_new.DevType.str.split(";").to_list()
len(a)
# Out:
# 61302
