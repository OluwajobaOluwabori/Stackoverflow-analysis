# %% [markdown]
# # Project: Investigate how developers are transitioning into tech
# ## Introduction
# ### Dataset Description
#
#
#
# To proceed with this analysis, I would be answering some Questions which are:

# %%
#Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#read in the data and
df = pd.read_csv('survey_results_public.csv')

print(df.shape)

#Extracting the columns we need
df_new = df.iloc[:,np.r_[0,5,6,7,8,11,19:37,39:43,58]].reset_index(drop=True)
# Out:
# (73268, 79)

# %% [markdown]
# ##### There are 73,268 rows and 79 columns (i.e this data consists of 73,268 developers responses to 79 questions/sub-questions.                        The columns/questions we will be working with are printed below

# %%
df_new.columns,df_new.index
# Out:
# (Index(['ResponseId', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#         'LearnCodeCoursesCert', 'DevType', 'LanguageHaveWorkedWith',
#         'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#         'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#         'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#         'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#         'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#         'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#         'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#         'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#         'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
#         'OfficeStackSyncHaveWorkedWith', 'OfficeStackSyncWantToWorkWith',
#         'WorkExp'],
#        dtype='object'),
#  RangeIndex(start=0, stop=73268, step=1))

# %% [markdown]
# ## Data Cleaning
#
# Since most of our analysis is career based, we remove the null rows w.r.t to DevType column. And obtain the unique reponses for the multi-choice questions.

# %%
# Handling missing data
# Drop rows with no response to ''Which of the following describes your current job?''
df_new.dropna(subset =['DevType'],inplace=True)

df_new=df_new.reset_index(drop=True)

#df_new.dtypes

# %%
#Total number of response to the question 'Which of the following describes your current job?' (DevType) is 61302
df_new['DevType'].shape[0]
# Out:
# 61302

# %%
def unique_answers(column):
    '''
    
    This function obtains the unique answers(provided options) for any given question.
    
    INPUT 
        df - dataframe
        column - the column name you want to obtain the unique answers from.
        
    OUTPUT
    
        Unique_ans - A set containing all the possible (unique) answers in the column
    '''
    df1=df_new.dropna(subset = [column])
    Unique_vals = set()
    df1[column]=df1[column].str.split(';')
    for row in df1[column]:
        for role in row:
            Unique_vals.add(role)
    return(Unique_vals)

# %%
'''
Calling the function to obtain the possible(unique) answers for the necessary columns
Current & Next will always be the same.
'''
Unique_roles = unique_answers('DevType')
Unique_current_languages = unique_answers('LanguageHaveWorkedWith')
Unique_next_languages = unique_answers('LanguageWantToWorkWith')
Unique_current_db = unique_answers('DatabaseHaveWorkedWith')
Unique_next_db = unique_answers('DatabaseWantToWorkWith')
Unique_current_platform = unique_answers('PlatformHaveWorkedWith')
Unique_next_platform = unique_answers('PlatformWantToWorkWith')
Unique_current_Webframe = unique_answers('WebframeHaveWorkedWith')
Unique_next_Webframe = unique_answers('WebframeWantToWorkWith')
# Out:
# C:\Users\jobao\AppData\Local\Temp/ipykernel_16584/1741093959.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[column]=df1[column].str.split(';')

# %%
def split_multiple_answers(column):
    '''
    This function split the column with multiple answers and convert each cell into a string
    df - dataframe

    INPUT 
        
        column - the column name with multiple answers that needs to be splitted
        
    OUTPUT
    
        Splitted_col - A set containing all unique answers in the different rows
    '''
    df = df_new.dropna(subset = [column])
    df[column] = df[column].str.split(';')
    
    return(df[column])


df_new['DevType'] = split_multiple_answers('DevType')

# %%
df_new['DevType']
# Out:
# 0        [Data scientist or machine learning specialist...
# 1                                  [Developer, full-stack]
# 2        [Developer, front-end, Developer, full-stack, ...
# 3                         [Developer, full-stack, Student]
# 4                                    [Developer, back-end]
#                                ...
# 61297                                [Developer, back-end]
# 61298      [Data scientist or machine learning specialist]
# 61299    [Developer, full-stack, Developer, desktop or ...
# 61300    [Developer, front-end, Developer, desktop or e...
# 61301    [Developer, front-end, Engineer, data, Enginee...
# Name: DevType, Length: 61302, dtype: object

# %%
'''
Using Pandas melt function to convert list-like column elements to separate rows 

1. Split DevType column list values (columns with individual list values are created).

2. Merge the new columns with the rest of the data set.

3. Drop the old names list column and then transform the new columns into separate rows using the melt function.

4. Additional column ‘variable’ containing the ids of the numeric columns is seen. This column is dropped and empty values are removed.'''

df_clean=df_new.DevType.apply(pd.Series) \
   .merge(df_new, right_index = True, left_index = True) \
   .drop(["DevType"], axis = 1) \
   .melt(id_vars = df.iloc[:,np.r_[0,5,6,7,8,19:37,39:43,58]], value_name = "DevType")\
   .dropna(subset=['DevType'])\
   .drop("variable", axis=1)

# %% [markdown]
# ##### Responses to the question 'Which of the following describes your current job? Please select all that apply.' is now splitted into different rows according to the respective ids.

# %%
df_clean.head(10)
# Out:
#    ResponseId                                         MainBranch  \
# 0           3  I am not primarily a developer, but I write co...
# 1           4                     I am a developer by profession
# 2           5                     I am a developer by profession
# 3           8                     I am a developer by profession
# 4           9                     I am a developer by profession
# 5          10                     I am a developer by profession
# 6          11                     I am a developer by profession
# 7          12  I am not primarily a developer, but I write co...
# 8          13                     I am a developer by profession
# 9          14                     I am a developer by profession
#
#                                           Employment  \
# 0                                Employed, full-time
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                 Not employed, but looking for work
# 4                                Employed, full-time
# 5  Independent contractor, freelancer, or self-em...
# 6                                Employed, full-time
# 7  Employed, full-time;Independent contractor, fr...
# 8                                Employed, full-time
# 9                                Employed, part-time
#
#                              RemoteWork  \
# 0  Hybrid (some remote, some in-person)
# 1                          Fully remote
# 2  Hybrid (some remote, some in-person)
# 3                                   NaN
# 4  Hybrid (some remote, some in-person)
# 5                          Fully remote
# 6  Hybrid (some remote, some in-person)
# 7                          Fully remote
# 8  Hybrid (some remote, some in-person)
# 9                          Fully remote
#
#                                              EdLevel  \
# 0    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3  Some college/university study without earning ...
# 4    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5  Some college/university study without earning ...
# 6       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 7       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 8       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0  Books / Physical media;Friend or family member...
# 1  Books / Physical media;School (i.e., Universit...
# 2  Other online resources (e.g., videos, blogs, f...
# 3                    Online Courses or Certification
# 4                On the job training;Coding Bootcamp
# 5  Books / Physical media;Other online resources ...
# 6  Books / Physical media;Friend or family member...
# 7  Other online resources (e.g., videos, blogs, f...
# 8            School (i.e., University, College, etc)
# 9  Books / Physical media;School (i.e., Universit...
#
#                                      LearnCodeOnline LearnCodeCoursesCert  \
# 0  Technical documentation;Blogs;Programming Game...                  NaN
# 1                                                NaN                  NaN
# 2  Technical documentation;Blogs;Stack Overflow;O...                  NaN
# 3                                                NaN       Coursera;Udemy
# 4                                                NaN                  NaN
# 5  Technical documentation;Blogs;Written Tutorial...                  NaN
# 6  Technical documentation;Blogs;Written Tutorial...                  NaN
# 7  Technical documentation;Blogs;Written Tutorial...                  NaN
# 8                                                NaN                  NaN
# 9                                                NaN                  NaN
#
#   YearsCode YearsCodePro  ...                      OpSysProfessional use  \
# 0        14            5  ...                                    Windows
# 1        20           17  ...                                    Windows
# 2         8            3  ...                                    Windows
# 3         1          NaN  ...                          Linux-based;macOS
# 4         6            6  ...                                    Windows
# 5        37           30  ...                                    Windows
# 6         5            2  ...  Windows;Windows Subsystem for Linux (WSL)
# 7        12           10  ...                  Linux-based;macOS;Windows
# 8        12            5  ...                                      macOS
# 9        22           15  ...                                      macOS
#
#    OpSysPersonal use         VersionControlSystem  \
# 0            Windows                          Git
# 1            Windows                          Git
# 2      macOS;Windows  Git;Other (please specify):
# 3            Windows                          Git
# 4            Windows                          Git
# 5            Windows                          Git
# 6        Linux-based                          Git
# 7  Linux-based;macOS                          Git
# 8        Linux-based                          Git
# 9              macOS                          Git
#
#                                        VCInteraction  \
# 0                                        Code editor
# 1  Code editor;Command-line;Version control hosti...
# 2                                        Code editor
# 3                                       Command-line
# 4  Command-line;Dedicated version control GUI app...
# 5  Version control hosting service web GUI;Dedica...
# 6                           Code editor;Command-line
# 7  Code editor;Dedicated version control GUI appl...
# 8                           Code editor;Command-line
# 9                                       Command-line
#
#                       OfficeStackAsyncHaveWorkedWith  \
# 0                                                NaN
# 1                        Jira Work Management;Trello
# 2                                                NaN
# 3                                                NaN
# 4                    Confluence;Jira Work Management
# 5                                                NaN
# 6                                         Confluence
# 7      Confluence;Jira Work Management;Notion;Trello
# 8                        Jira Work Management;Trello
# 9  Airtable;Confluence;Jira Work Management;Notio...
#
#     OfficeStackAsyncWantToWorkWith  \
# 0                              NaN
# 1      Jira Work Management;Trello
# 2                              NaN
# 3                              NaN
# 4  Confluence;Jira Work Management
# 5                              NaN
# 6                              NaN
# 7                    Notion;Trello
# 8      Jira Work Management;Trello
# 9                           Notion
#
#                        OfficeStackSyncHaveWorkedWith  \
# 0                                    Microsoft Teams
# 1                                         Slack;Zoom
# 2                               Microsoft Teams;Zoom
# 3                   Google Chat;Microsoft Teams;Zoom
# 4                                    Microsoft Teams
# 5                                  Google Chat;Slack
# 6             Google Chat;Microsoft Teams;Slack;Zoom
# 7  Cisco Webex Teams;Google Chat;Microsoft Teams;...
# 8                         Microsoft Teams;Slack;Zoom
# 9                         Microsoft Teams;Slack;Zoom
#
#   OfficeStackSyncWantToWorkWith WorkExp  \
# 0               Microsoft Teams     NaN
# 1                    Slack;Zoom     NaN
# 2                           NaN     NaN
# 3                           NaN     NaN
# 4               Microsoft Teams     6.0
# 5             Google Chat;Slack     NaN
# 6             Google Chat;Slack     NaN
# 7                         Slack    14.0
# 8         Microsoft Teams;Slack     5.0
# 9                    Slack;Zoom    15.0
#
#                                          DevType
# 0  Data scientist or machine learning specialist
# 1                          Developer, full-stack
# 2                           Developer, front-end
# 3                          Developer, full-stack
# 4                            Developer, back-end
# 5  Developer, desktop or enterprise applications
# 6                          Developer, full-stack
# 7                            Engineering manager
# 8                          Developer, full-stack
# 9                           Developer, front-end
#
# [10 rows x 35 columns]

# %%
df_new.DevType[2]
# Out:
# ['Developer, front-end',
#  'Developer, full-stack',
#  'Developer, back-end',
#  'Developer, desktop or enterprise applications',
#  'Developer, QA or test']

# %%
df_clean[df_clean.ResponseId==5]
# Out:
#         ResponseId                      MainBranch           Employment  \
# 2                5  I am a developer by profession  Employed, full-time
# 61304            5  I am a developer by profession  Employed, full-time
# 122606           5  I am a developer by profession  Employed, full-time
# 183908           5  I am a developer by profession  Employed, full-time
# 245210           5  I am a developer by profession  Employed, full-time
#
#                                   RemoteWork  \
# 2       Hybrid (some remote, some in-person)
# 61304   Hybrid (some remote, some in-person)
# 122606  Hybrid (some remote, some in-person)
# 183908  Hybrid (some remote, some in-person)
# 245210  Hybrid (some remote, some in-person)
#
#                                              EdLevel  \
# 2       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 61304   Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 122606  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 183908  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 245210  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                 LearnCode  \
# 2       Other online resources (e.g., videos, blogs, f...
# 61304   Other online resources (e.g., videos, blogs, f...
# 122606  Other online resources (e.g., videos, blogs, f...
# 183908  Other online resources (e.g., videos, blogs, f...
# 245210  Other online resources (e.g., videos, blogs, f...
#
#                                           LearnCodeOnline  \
# 2       Technical documentation;Blogs;Stack Overflow;O...
# 61304   Technical documentation;Blogs;Stack Overflow;O...
# 122606  Technical documentation;Blogs;Stack Overflow;O...
# 183908  Technical documentation;Blogs;Stack Overflow;O...
# 245210  Technical documentation;Blogs;Stack Overflow;O...
#
#        LearnCodeCoursesCert YearsCode YearsCodePro  ... OpSysProfessional use  \
# 2                       NaN         8            3  ...               Windows
# 61304                   NaN         8            3  ...               Windows
# 122606                  NaN         8            3  ...               Windows
# 183908                  NaN         8            3  ...               Windows
# 245210                  NaN         8            3  ...               Windows
#
#        OpSysPersonal use         VersionControlSystem VCInteraction  \
# 2          macOS;Windows  Git;Other (please specify):   Code editor
# 61304      macOS;Windows  Git;Other (please specify):   Code editor
# 122606     macOS;Windows  Git;Other (please specify):   Code editor
# 183908     macOS;Windows  Git;Other (please specify):   Code editor
# 245210     macOS;Windows  Git;Other (please specify):   Code editor
#
#        OfficeStackAsyncHaveWorkedWith OfficeStackAsyncWantToWorkWith  \
# 2                                 NaN                            NaN
# 61304                             NaN                            NaN
# 122606                            NaN                            NaN
# 183908                            NaN                            NaN
# 245210                            NaN                            NaN
#
#        OfficeStackSyncHaveWorkedWith OfficeStackSyncWantToWorkWith WorkExp  \
# 2               Microsoft Teams;Zoom                           NaN     NaN
# 61304           Microsoft Teams;Zoom                           NaN     NaN
# 122606          Microsoft Teams;Zoom                           NaN     NaN
# 183908          Microsoft Teams;Zoom                           NaN     NaN
# 245210          Microsoft Teams;Zoom                           NaN     NaN
#
#                                               DevType
# 2                                Developer, front-end
# 61304                           Developer, full-stack
# 122606                            Developer, back-end
# 183908  Developer, desktop or enterprise applications
# 245210                          Developer, QA or test
#
# [5 rows x 35 columns]

# %% [markdown]
# ##  Exploratory Data Analysis

# %% [markdown]
# Let's ensure that the columns we would be considering for analysis don't contain lots of missing values.

# %%
#Which column has most of their values missing
df_clean.columns[df_clean.isnull().mean() >= 0.5]
# Out:
# Index(['LearnCodeCoursesCert', 'OfficeStackAsyncWantToWorkWith'], dtype='object')

# %%
'''
This shows that 2 columns have more than half of their values missing - 

LearnCodeCoursesCert   and OfficeStackAsyncWantToWorkWith

'''
#df_new.isnull().mean()
df_clean.isnull().mean()
# Out:
# ResponseId                        0.000000
# MainBranch                        0.000000
# Employment                        0.000000
# RemoteWork                        0.033570
# EdLevel                           0.001311
# LearnCode                         0.001165
# LearnCodeOnline                   0.270726
# LearnCodeCoursesCert              0.582723
# YearsCode                         0.004424
# YearsCodePro                      0.163833
# OrgSize                           0.174106
# LanguageHaveWorkedWith            0.005735
# LanguageWantToWorkWith            0.059099
# DatabaseHaveWorkedWith            0.099848
# DatabaseWantToWorkWith            0.214176
# PlatformHaveWorkedWith            0.234948
# PlatformWantToWorkWith            0.361624
# WebframeHaveWorkedWith            0.190813
# WebframeWantToWorkWith            0.293027
# MiscTechHaveWorkedWith            0.313417
# MiscTechWantToWorkWith            0.424832
# ToolsTechHaveWorkedWith           0.203046
# ToolsTechWantToWorkWith           0.301560
# NEWCollabToolsHaveWorkedWith      0.013235
# NEWCollabToolsWantToWorkWith      0.093986
# OpSysProfessional use             0.046793
# OpSysPersonal use                 0.010322
# VersionControlSystem              0.003435
# VCInteraction                     0.034353
# OfficeStackAsyncHaveWorkedWith    0.308866
# OfficeStackAsyncWantToWorkWith    0.511123
# OfficeStackSyncHaveWorkedWith     0.091881
# OfficeStackSyncWantToWorkWith     0.278360
# WorkExp                           0.397008
# DevType                           0.000000
# dtype: float64

# %%
df_new['DevType'][10]
# Out:
# ['Developer, full-stack', 'Academic researcher', 'DevOps specialist']

# %% [markdown]
# Let's find the proportion of each role
#
# From the code below, the majority of respondents are Developers

# %%
DevType_count=(df_clean['DevType'].value_counts()/df_new['DevType'].shape[0]).mul(100).reset_index().rename(columns={'index':'Role','DevType':'count'})
DevType_count.columns=['Role','count']
DevType_count
# Out:
#                                              Role      count
# 0                           Developer, full-stack  46.819027
# 1                             Developer, back-end  43.383576
# 2                            Developer, front-end  25.961633
# 3   Developer, desktop or enterprise applications  15.572086
# 4                               Developer, mobile  12.453101
# 5                               DevOps specialist  10.064924
# 6                                         Student   9.126945
# 7                   Cloud infrastructure engineer   8.617990
# 8                          Database administrator   8.048677
# 9                            System administrator   8.006264
# 10    Developer, embedded applications or devices   6.399465
# 11                                Project manager   6.357052
# 12                                       Designer   6.140093
# 13                                 Engineer, data   5.872565
# 14                            Engineering manager   5.830152
# 15  Data scientist or machine learning specialist   5.585462
# 16                       Data or business analyst   5.221689
# 17                          Developer, QA or test   5.050406
# 18                            Academic researcher   4.419105
# 19                        Other (please specify):   4.270660
# 20                                Product manager   4.101008
# 21                                       Educator   3.409350
# 22                     Engineer, site reliability   3.176079
# 23                          Security professional   3.145085
# 24                    Developer, game or graphics   2.996640
# 25           Senior Executive (C-Suite, VP, etc.)   2.944439
# 26                                      Scientist   2.874294
# 27                                     Blockchain   2.123911
# 28                Marketing or sales professional   0.844997

# %%
# A horizontal bar chart showing the proportion

plt.figure(figsize=(10,10))
plt.barh(DevType_count['Role'],DevType_count['count'])
plt.title("Which of the following describes your current job?")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The roles we would be considering are;
# 1. Data or business analyst
# 2. Data scientist or machine learning specialist
# 3. Developer, back-end
# 4. Developer, front-end
# 5. Developer, full-stack
# 6. DevOps specialist
# 7. Designer
# 8. Developer, embedded applications or devices

# %% [markdown]
# #### The average years of experience for the different roles

# %%
#The average years of experience for the different roles
df_clean.groupby(['DevType'])['WorkExp'].mean().sort_values()
# Out:
# DevType
# Student                                           5.032353
# Developer, front-end                              9.822250
# Developer, mobile                                10.379075
# Data scientist or machine learning specialist    10.380952
# Developer, full-stack                            10.386392
# Developer, back-end                              10.651393
# Blockchain                                       10.679144
# Academic researcher                              10.806090
# Developer, QA or test                            11.554845
# Engineer, data                                   11.702923
# Developer, game or graphics                      11.969399
# Cloud infrastructure engineer                    12.189419
# DevOps specialist                                12.407099
# Scientist                                        12.410169
# Developer, embedded applications or devices      12.638144
# Engineer, site reliability                       13.036458
# Developer, desktop or enterprise applications    13.243355
# Educator                                         13.492188
# Other (please specify):                          13.550661
# Data or business analyst                         13.561910
# System administrator                             13.663614
# Database administrator                           13.861258
# Designer                                         13.871068
# Project manager                                  14.106239
# Security professional                            14.865401
# Engineering manager                              15.190323
# Product manager                                  15.230769
# Marketing or sales professional                  16.793991
# Senior Executive (C-Suite, VP, etc.)             18.165605
# Name: WorkExp, dtype: float64

# %%
#What proportion of values are missing on each column w.r.t the DevType column
# Create a DataFrame index object/pandas series
idx = pd.Index(sorted(Unique_roles))
#idx = pd.Series(sorted(Unique_roles))


Describe= pd.DataFrame()

for role in sorted(Unique_roles):
    Describe=Describe.append(df_clean[df_clean['DevType']==role].isnull().mean(),ignore_index=True)
    #Describe=pd.concat([Describe,pd.Series(role)])
    
# Set the above DataFrame index object as the index
# using set_index() function
Describe.set_index(idx,inplace=True)
Describe
# Out:
#                                                ResponseId   EdLevel  \
# Academic researcher                                   0.0  0.001107
# Blockchain                                            0.0  0.002304
# Cloud infrastructure engineer                         0.0  0.000568
# Data or business analyst                              0.0  0.001562
# Data scientist or machine learning specialist         0.0  0.000876
# Database administrator                                0.0  0.001419
# Designer                                              0.0  0.002391
# DevOps specialist                                     0.0  0.000324
# Developer, QA or test                                 0.0  0.002261
# Developer, back-end                                   0.0  0.001166
# Developer, desktop or enterprise applications         0.0  0.000943
# Developer, embedded applications or devices           0.0  0.001784
# Developer, front-end                                  0.0  0.001759
# Developer, full-stack                                 0.0  0.001010
# Developer, game or graphics                           0.0  0.002177
# Developer, mobile                                     0.0  0.001179
# Educator                                              0.0  0.001435
# Engineer, data                                        0.0  0.001667
# Engineer, site reliability                            0.0  0.002568
# Engineering manager                                   0.0  0.001119
# Marketing or sales professional                       0.0  0.007722
# Other (please specify):                               0.0  0.001910
# Product manager                                       0.0  0.001193
# Project manager                                       0.0  0.001026
# Scientist                                             0.0  0.001703
# Security professional                                 0.0  0.001556
# Senior Executive (C-Suite, VP, etc.)                  0.0  0.001108
# Student                                               0.0  0.001609
# System administrator                                  0.0  0.001222
#
#                                                LearnCode  LearnCodeOnline  \
# Academic researcher                             0.002215         0.310447
# Blockchain                                      0.003072         0.281106
# Cloud infrastructure engineer                   0.000757         0.274276
# Data or business analyst                        0.000937         0.246798
# Data scientist or machine learning specialist   0.000876         0.286215
# Database administrator                          0.001013         0.249493
# Designer                                        0.001328         0.241764
# DevOps specialist                               0.000972         0.262237
# Developer, QA or test                           0.001615         0.249031
# Developer, back-end                             0.000978         0.293063
# Developer, desktop or enterprise applications   0.000943         0.294783
# Developer, embedded applications or devices     0.002294         0.310986
# Developer, front-end                            0.000943         0.241533
# Developer, full-stack                           0.000906         0.275217
# Developer, game or graphics                     0.001633         0.256941
# Developer, mobile                               0.001572         0.263689
# Educator                                        0.000957         0.255981
# Engineer, data                                  0.000833         0.277778
# Engineer, site reliability                      0.002054         0.250642
# Engineering manager                             0.001119         0.314773
# Marketing or sales professional                 0.007722         0.245174
# Other (please specify):                         0.002292         0.301375
# Product manager                                 0.001193         0.268496
# Project manager                                 0.000770         0.265589
# Scientist                                       0.002270         0.298524
# Security professional                           0.001556         0.248444
# Senior Executive (C-Suite, VP, etc.)            0.001108         0.304709
# Student                                         0.001430         0.188561
# System administrator                            0.001019         0.247963
#
#                                                LearnCodeCoursesCert  \
# Academic researcher                                        0.660391
# Blockchain                                                 0.557604
# Cloud infrastructure engineer                              0.589816
# Data or business analyst                                   0.492971
# Data scientist or machine learning specialist              0.533879
# Database administrator                                     0.604378
# Designer                                                   0.583953
# DevOps specialist                                          0.590276
# Developer, QA or test                                      0.563307
# Developer, back-end                                        0.589284
# Developer, desktop or enterprise applications              0.625602
# Developer, embedded applications or devices                0.680347
# Developer, front-end                                       0.528432
# Developer, full-stack                                      0.570816
# Developer, game or graphics                                0.671747
# Developer, mobile                                          0.536547
# Educator                                                   0.583732
# Engineer, data                                             0.557500
# Engineer, site reliability                                 0.613251
# Engineering manager                                        0.637101
# Marketing or sales professional                            0.521236
# Other (please specify):                                    0.582124
# Product manager                                            0.608990
# Project manager                                            0.597383
# Scientist                                                  0.677072
# Security professional                                      0.644710
# Senior Executive (C-Suite, VP, etc.)                       0.657618
# Student                                                    0.518856
# System administrator                                       0.633863
#
#                                                LanguageHaveWorkedWith  \
# Academic researcher                                          0.011074
# Blockchain                                                   0.013057
# Cloud infrastructure engineer                                0.003596
# Data or business analyst                                     0.008435
# Data scientist or machine learning specialist                0.004089
# Database administrator                                       0.004054
# Designer                                                     0.008767
# DevOps specialist                                            0.004214
# Developer, QA or test                                        0.005168
# Developer, back-end                                          0.003497
# Developer, desktop or enterprise applications                0.004505
# Developer, embedded applications or devices                  0.005353
# Developer, front-end                                         0.004587
# Developer, full-stack                                        0.003798
# Developer, game or graphics                                  0.008165
# Developer, mobile                                            0.004323
# Educator                                                     0.010526
# Engineer, data                                               0.004167
# Engineer, site reliability                                   0.006163
# Engineering manager                                          0.005036
# Marketing or sales professional                              0.042471
# Other (please specify):                                      0.029412
# Product manager                                              0.006762
# Project manager                                              0.005645
# Scientist                                                    0.004540
# Security professional                                        0.008299
# Senior Executive (C-Suite, VP, etc.)                         0.008310
# Student                                                      0.013941
# System administrator                                         0.006927
#
#                                                LanguageWantToWorkWith  \
# Academic researcher                                          0.064599
# Blockchain                                                   0.075269
# Cloud infrastructure engineer                                0.057732
# Data or business analyst                                     0.073102
# Data scientist or machine learning specialist                0.057827
# Database administrator                                       0.063032
# Designer                                                     0.073592
# DevOps specialist                                            0.053160
# Developer, QA or test                                        0.064276
# Developer, back-end                                          0.052228
# Developer, desktop or enterprise applications                0.058140
# Developer, embedded applications or devices                  0.060668
# Developer, front-end                                         0.058310
# Developer, full-stack                                        0.054493
# Developer, game or graphics                                  0.066957
# Developer, mobile                                            0.062353
# Educator                                                     0.052153
# Engineer, data                                               0.064444
# Engineer, site reliability                                   0.050847
# Engineering manager                                          0.067711
# Marketing or sales professional                              0.127413
# Other (please specify):                                      0.084034
# Product manager                                              0.070804
# Project manager                                              0.063895
# Scientist                                                    0.057321
# Security professional                                        0.064834
# Senior Executive (C-Suite, VP, etc.)                         0.080332
# Student                                                      0.046470
# System administrator                                         0.064181
#
#                                                DatabaseHaveWorkedWith  \
# Academic researcher                                          0.310078
# Blockchain                                                   0.111367
# Cloud infrastructure engineer                                0.054325
# Data or business analyst                                     0.085911
# Data scientist or machine learning specialist                0.165012
# Database administrator                                       0.025132
# Designer                                                     0.121945
# DevOps specialist                                            0.057699
# Developer, QA or test                                        0.106266
# Developer, back-end                                          0.061102
# Developer, desktop or enterprise applications                0.129164
# Developer, embedded applications or devices                  0.258731
# Developer, front-end                                         0.121772
# Developer, full-stack                                        0.047664
# Developer, game or graphics                                  0.247142
# Developer, mobile                                            0.119990
# Educator                                                     0.168421
# Engineer, data                                               0.086111
# Engineer, site reliability                                   0.060092
# Engineering manager                                          0.086178
# Marketing or sales professional                              0.137066
# Other (please specify):                                      0.258212
# Product manager                                              0.083930
# Project manager                                              0.077752
# Scientist                                                    0.333144
# Security professional                                        0.113071
# Senior Executive (C-Suite, VP, etc.)                         0.055956
# Student                                                      0.170509
# System administrator                                         0.064588
#
#                                                DatabaseWantToWorkWith  \
# Academic researcher                                          0.447398
# Blockchain                                                   0.263441
# Cloud infrastructure engineer                                0.164111
# Data or business analyst                                     0.207435
# Data scientist or machine learning specialist                0.311040
# Database administrator                                       0.116336
# Designer                                                     0.248937
# DevOps specialist                                            0.169206
# Developer, QA or test                                        0.231912
# Developer, back-end                                          0.168490
# Developer, desktop or enterprise applications                0.248062
# Developer, embedded applications or devices                  0.390772
# Developer, front-end                                         0.239585
# Developer, full-stack                                        0.158392
# Developer, game or graphics                                  0.384867
# Developer, mobile                                            0.244433
# Educator                                                     0.270335
# Engineer, data                                               0.203333
# Engineer, site reliability                                   0.162815
# Engineering manager                                          0.191662
# Marketing or sales professional                              0.270270
# Other (please specify):                                      0.378915
# Product manager                                              0.193715
# Project manager                                              0.184758
# Scientist                                                    0.460272
# Security professional                                        0.232365
# Senior Executive (C-Suite, VP, etc.)                         0.171745
# Student                                                      0.275961
# System administrator                                         0.164018
#
#                                                PlatformHaveWorkedWith  ...  \
# Academic researcher                                          0.433739  ...
# Blockchain                                                   0.180492  ...
# Cloud infrastructure engineer                                0.044293  ...
# Data or business analyst                                     0.255858  ...
# Data scientist or machine learning specialist                0.241530  ...
# Database administrator                                       0.219092  ...
# Designer                                                     0.295962  ...
# DevOps specialist                                            0.115721  ...
# Developer, QA or test                                        0.251938  ...
# Developer, back-end                                          0.219853  ...
# Developer, desktop or enterprise applications                0.344961  ...
# Developer, embedded applications or devices                  0.391027  ...
# Developer, front-end                                         0.252843  ...
# Developer, full-stack                                        0.206543  ...
# Developer, game or graphics                                  0.336418  ...
# Developer, mobile                                            0.207362  ...
# Educator                                                     0.296651  ...
# Engineer, data                                               0.200000  ...
# Engineer, site reliability                                   0.112994  ...
# Engineering manager                                          0.134583  ...
# Marketing or sales professional                              0.249035  ...
# Other (please specify):                                      0.385791  ...
# Product manager                                              0.196102  ...
# Project manager                                              0.229664  ...
# Scientist                                                    0.444381  ...
# Security professional                                        0.182573  ...
# Senior Executive (C-Suite, VP, etc.)                         0.136288  ...
# Student                                                      0.338338  ...
# System administrator                                         0.217808  ...
#
#                                                OpSysProfessional use  \
# Academic researcher                                         0.057217
# Blockchain                                                  0.082181
# Cloud infrastructure engineer                               0.032936
# Data or business analyst                                    0.054983
# Data scientist or machine learning specialist               0.047313
# Database administrator                                      0.045602
# Designer                                                    0.060840
# DevOps specialist                                           0.033712
# Developer, QA or test                                       0.044574
# Developer, back-end                                         0.039067
# Developer, desktop or enterprise applications               0.040436
# Developer, embedded applications or devices                 0.042824
# Developer, front-end                                        0.046748
# Developer, full-stack                                       0.042821
# Developer, game or graphics                                 0.061513
# Developer, mobile                                           0.051873
# Educator                                                    0.049282
# Engineer, data                                              0.043056
# Engineer, site reliability                                  0.035953
# Engineering manager                                         0.041410
# Marketing or sales professional                             0.096525
# Other (please specify):                                     0.088235
# Product manager                                             0.046539
# Project manager                                             0.048499
# Scientist                                                   0.042565
# Security professional                                       0.037344
# Senior Executive (C-Suite, VP, etc.)                        0.044875
# Student                                                     0.102770
# System administrator                                        0.039935
#
#                                                OpSysPersonal use  \
# Academic researcher                                     0.017350
# Blockchain                                              0.019201
# Cloud infrastructure engineer                           0.007382
# Data or business analyst                                0.017182
# Data scientist or machine learning specialist           0.014311
# Database administrator                                  0.011350
# Designer                                                0.015409
# DevOps specialist                                       0.007780
# Developer, QA or test                                   0.012274
# Developer, back-end                                     0.008836
# Developer, desktop or enterprise applications           0.009533
# Developer, embedded applications or devices             0.012490
# Developer, front-end                                    0.009048
# Developer, full-stack                                   0.007700
# Developer, game or graphics                             0.010887
# Developer, mobile                                       0.010610
# Educator                                                0.014354
# Engineer, data                                          0.013333
# Engineer, site reliability                              0.011813
# Engineering manager                                     0.010632
# Marketing or sales professional                         0.042471
# Other (please specify):                                 0.015279
# Product manager                                         0.012729
# Project manager                                         0.012574
# Scientist                                               0.011918
# Security professional                                   0.017116
# Senior Executive (C-Suite, VP, etc.)                    0.014958
# Student                                                 0.007507
# System administrator                                    0.008150
#
#                                                VersionControlSystem  \
# Academic researcher                                        0.008859
# Blockchain                                                 0.005376
# Cloud infrastructure engineer                              0.002082
# Data or business analyst                                   0.007810
# Data scientist or machine learning specialist              0.004965
# Database administrator                                     0.005067
# Designer                                                   0.007705
# DevOps specialist                                          0.001945
# Developer, QA or test                                      0.003230
# Developer, back-end                                        0.002369
# Developer, desktop or enterprise applications              0.003352
# Developer, embedded applications or devices                0.004079
# Developer, front-end                                       0.002639
# Developer, full-stack                                      0.001742
# Developer, game or graphics                                0.004355
# Developer, mobile                                          0.003537
# Educator                                                   0.006699
# Engineer, data                                             0.004167
# Engineer, site reliability                                 0.004109
# Engineering manager                                        0.001679
# Marketing or sales professional                            0.013514
# Other (please specify):                                    0.008785
# Product manager                                            0.003580
# Project manager                                            0.004106
# Scientist                                                  0.006810
# Security professional                                      0.004149
# Senior Executive (C-Suite, VP, etc.)                       0.003878
# Student                                                    0.003932
# System administrator                                       0.004279
#
#                                                VCInteraction  \
# Academic researcher                                 0.056478
# Blockchain                                          0.026882
# Cloud infrastructure engineer                       0.009275
# Data or business analyst                            0.096845
# Data scientist or machine learning specialist       0.047897
# Database administrator                              0.061005
# Designer                                            0.072795
# DevOps specialist                                   0.008590
# Developer, QA or test                               0.024871
# Developer, back-end                                 0.019214
# Developer, desktop or enterprise applications       0.045150
# Developer, embedded applications or devices         0.036197
# Developer, front-end                                0.027207
# Developer, full-stack                               0.019198
# Developer, game or graphics                         0.049537
# Developer, mobile                                   0.032748
# Educator                                            0.055024
# Engineer, data                                      0.047500
# Engineer, site reliability                          0.020544
# Engineering manager                                 0.018747
# Marketing or sales professional                     0.164093
# Other (please specify):                             0.097021
# Product manager                                     0.040971
# Project manager                                     0.047986
# Scientist                                           0.058456
# Security professional                               0.034751
# Senior Executive (C-Suite, VP, etc.)                0.036011
# Student                                             0.057015
# System administrator                                0.052975
#
#                                                OfficeStackAsyncHaveWorkedWith  \
# Academic researcher                                                  0.514581
# Blockchain                                                           0.228879
# Cloud infrastructure engineer                                        0.212569
# Data or business analyst                                             0.359575
# Data scientist or machine learning specialist                        0.323890
# Database administrator                                               0.365829
# Designer                                                             0.391870
# DevOps specialist                                                    0.227877
# Developer, QA or test                                                0.279070
# Developer, back-end                                                  0.273059
# Developer, desktop or enterprise applications                        0.392625
# Developer, embedded applications or devices                          0.360693
# Developer, front-end                                                 0.287276
# Developer, full-stack                                                0.286784
# Developer, game or graphics                                          0.329341
# Developer, mobile                                                    0.282028
# Educator                                                             0.389952
# Engineer, data                                                       0.274167
# Engineer, site reliability                                           0.229584
# Engineering manager                                                  0.193061
# Marketing or sales professional                                      0.345560
# Other (please specify):                                              0.404889
# Product manager                                                      0.313842
# Project manager                                                      0.313831
# Scientist                                                            0.486947
# Security professional                                                0.306017
# Senior Executive (C-Suite, VP, etc.)                                 0.283102
# Student                                                              0.415371
# System administrator                                                 0.369601
#
#                                                OfficeStackAsyncWantToWorkWith  \
# Academic researcher                                                  0.673311
# Blockchain                                                           0.453149
# Cloud infrastructure engineer                                        0.462995
# Data or business analyst                                             0.541081
# Data scientist or machine learning specialist                        0.525409
# Database administrator                                               0.548439
# Designer                                                             0.560043
# DevOps specialist                                                    0.465640
# Developer, QA or test                                                0.481589
# Developer, back-end                                                  0.495055
# Developer, desktop or enterprise applications                        0.578776
# Developer, embedded applications or devices                          0.585011
# Developer, front-end                                                 0.482815
# Developer, full-stack                                                0.493920
# Developer, game or graphics                                          0.530757
# Developer, mobile                                                    0.476683
# Educator                                                             0.555981
# Engineer, data                                                       0.485556
# Engineer, site reliability                                           0.468413
# Engineering manager                                                  0.409905
# Marketing or sales professional                                      0.513514
# Other (please specify):                                              0.578686
# Product manager                                                      0.485680
# Project manager                                                      0.489351
# Scientist                                                            0.659478
# Security professional                                                0.532158
# Senior Executive (C-Suite, VP, etc.)                                 0.469806
# Student                                                              0.571046
# System administrator                                                 0.564792
#
#                                                OfficeStackSyncHaveWorkedWith  \
# Academic researcher                                                 0.095607
# Blockchain                                                          0.122888
# Cloud infrastructure engineer                                       0.039182
# Data or business analyst                                            0.087160
# Data scientist or machine learning specialist                       0.070678
# Database administrator                                              0.118160
# Designer                                                            0.144793
# DevOps specialist                                                   0.046353
# Developer, QA or test                                               0.067829
# Developer, back-end                                                 0.079601
# Developer, desktop or enterprise applications                       0.107584
# Developer, embedded applications or devices                         0.099924
# Developer, front-end                                                0.092366
# Developer, full-stack                                               0.082541
# Developer, game or graphics                                         0.185084
# Developer, mobile                                                   0.109641
# Educator                                                            0.090909
# Engineer, data                                                      0.062222
# Engineer, site reliability                                          0.059065
# Engineering manager                                                 0.040851
# Marketing or sales professional                                     0.158301
# Other (please specify):                                             0.139037
# Product manager                                                     0.101432
# Project manager                                                     0.110598
# Scientist                                                           0.077753
# Security professional                                               0.101660
# Senior Executive (C-Suite, VP, etc.)                                0.076454
# Student                                                             0.170867
# System administrator                                                0.118989
#
#                                                OfficeStackSyncWantToWorkWith  \
# Academic researcher                                                 0.301956
# Blockchain                                                          0.329493
# Cloud infrastructure engineer                                       0.208404
# Data or business analyst                                            0.272102
# Data scientist or machine learning specialist                       0.264019
# Database administrator                                              0.299554
# Designer                                                            0.342721
# DevOps specialist                                                   0.218801
# Developer, QA or test                                               0.257752
# Developer, back-end                                                 0.263019
# Developer, desktop or enterprise applications                       0.298240
# Developer, embedded applications or devices                         0.318634
# Developer, front-end                                                0.273264
# Developer, full-stack                                               0.270200
# Developer, game or graphics                                         0.401742
# Developer, mobile                                                   0.293293
# Educator                                                            0.279904
# Engineer, data                                                      0.239167
# Engineer, site reliability                                          0.216744
# Engineering manager                                                 0.193621
# Marketing or sales professional                                     0.326255
# Other (please specify):                                             0.325439
# Product manager                                                     0.268099
# Project manager                                                     0.280472
# Scientist                                                           0.279796
# Security professional                                               0.288900
# Senior Executive (C-Suite, VP, etc.)                                0.249307
# Student                                                             0.401251
# System administrator                                                0.319071
#
#                                                 WorkExp  DevType
# Academic researcher                            0.539313      0.0
# Blockchain                                     0.425499      0.0
# Cloud infrastructure engineer                  0.309483      0.0
# Data or business analyst                       0.404561      0.0
# Data scientist or machine learning specialist  0.417348      0.0
# Database administrator                         0.387921      0.0
# Designer                                       0.484857      0.0
# DevOps specialist                              0.319611      0.0
# Developer, QA or test                          0.343346      0.0
# Developer, back-end                            0.357473      0.0
# Developer, desktop or enterprise applications  0.393044      0.0
# Developer, embedded applications or devices    0.401224      0.0
# Developer, front-end                           0.387747      0.0
# Developer, full-stack                          0.375283      0.0
# Developer, game or graphics                    0.501905      0.0
# Developer, mobile                              0.385250      0.0
# Educator                                       0.448804      0.0
# Engineer, data                                 0.353889      0.0
# Engineer, site reliability                     0.309707      0.0
# Engineering manager                            0.306100      0.0
# Marketing or sales professional                0.550193      0.0
# Other (please specify):                        0.479756      0.0
# Product manager                                0.400159      0.0
# Project manager                                0.391327      0.0
# Scientist                                      0.497730      0.0
# Security professional                          0.398859      0.0
# Senior Executive (C-Suite, VP, etc.)           0.391136      0.0
# Student                                        0.756926      0.0
# System administrator                           0.421557      0.0
#
# [29 rows x 29 columns]

# %%
Describe.head()
#print(f' Missing values:', {role},Describe.append(df_clean[df_clean['DevType']==role].isnull().mean(),ignore_index=True))
# Out:
#                                                ResponseId   EdLevel  \
# Academic researcher                                   0.0  0.001107
# Blockchain                                            0.0  0.002304
# Cloud infrastructure engineer                         0.0  0.000568
# Data or business analyst                              0.0  0.001562
# Data scientist or machine learning specialist         0.0  0.000876
#
#                                                LearnCode  LearnCodeOnline  \
# Academic researcher                             0.002215         0.310447
# Blockchain                                      0.003072         0.281106
# Cloud infrastructure engineer                   0.000757         0.274276
# Data or business analyst                        0.000937         0.246798
# Data scientist or machine learning specialist   0.000876         0.286215
#
#                                                LearnCodeCoursesCert  \
# Academic researcher                                        0.660391
# Blockchain                                                 0.557604
# Cloud infrastructure engineer                              0.589816
# Data or business analyst                                   0.492971
# Data scientist or machine learning specialist              0.533879
#
#                                                LanguageHaveWorkedWith  \
# Academic researcher                                          0.011074
# Blockchain                                                   0.013057
# Cloud infrastructure engineer                                0.003596
# Data or business analyst                                     0.008435
# Data scientist or machine learning specialist                0.004089
#
#                                                LanguageWantToWorkWith  \
# Academic researcher                                          0.064599
# Blockchain                                                   0.075269
# Cloud infrastructure engineer                                0.057732
# Data or business analyst                                     0.073102
# Data scientist or machine learning specialist                0.057827
#
#                                                DatabaseHaveWorkedWith  \
# Academic researcher                                          0.310078
# Blockchain                                                   0.111367
# Cloud infrastructure engineer                                0.054325
# Data or business analyst                                     0.085911
# Data scientist or machine learning specialist                0.165012
#
#                                                DatabaseWantToWorkWith  \
# Academic researcher                                          0.447398
# Blockchain                                                   0.263441
# Cloud infrastructure engineer                                0.164111
# Data or business analyst                                     0.207435
# Data scientist or machine learning specialist                0.311040
#
#                                                PlatformHaveWorkedWith  ...  \
# Academic researcher                                          0.433739  ...
# Blockchain                                                   0.180492  ...
# Cloud infrastructure engineer                                0.044293  ...
# Data or business analyst                                     0.255858  ...
# Data scientist or machine learning specialist                0.241530  ...
#
#                                                OpSysProfessional use  \
# Academic researcher                                         0.057217
# Blockchain                                                  0.082181
# Cloud infrastructure engineer                               0.032936
# Data or business analyst                                    0.054983
# Data scientist or machine learning specialist               0.047313
#
#                                                OpSysPersonal use  \
# Academic researcher                                     0.017350
# Blockchain                                              0.019201
# Cloud infrastructure engineer                           0.007382
# Data or business analyst                                0.017182
# Data scientist or machine learning specialist           0.014311
#
#                                                VersionControlSystem  \
# Academic researcher                                        0.008859
# Blockchain                                                 0.005376
# Cloud infrastructure engineer                              0.002082
# Data or business analyst                                   0.007810
# Data scientist or machine learning specialist              0.004965
#
#                                                VCInteraction  \
# Academic researcher                                 0.056478
# Blockchain                                          0.026882
# Cloud infrastructure engineer                       0.009275
# Data or business analyst                            0.096845
# Data scientist or machine learning specialist       0.047897
#
#                                                OfficeStackAsyncHaveWorkedWith  \
# Academic researcher                                                  0.514581
# Blockchain                                                           0.228879
# Cloud infrastructure engineer                                        0.212569
# Data or business analyst                                             0.359575
# Data scientist or machine learning specialist                        0.323890
#
#                                                OfficeStackAsyncWantToWorkWith  \
# Academic researcher                                                  0.673311
# Blockchain                                                           0.453149
# Cloud infrastructure engineer                                        0.462995
# Data or business analyst                                             0.541081
# Data scientist or machine learning specialist                        0.525409
#
#                                                OfficeStackSyncHaveWorkedWith  \
# Academic researcher                                                 0.095607
# Blockchain                                                          0.122888
# Cloud infrastructure engineer                                       0.039182
# Data or business analyst                                            0.087160
# Data scientist or machine learning specialist                       0.070678
#
#                                                OfficeStackSyncWantToWorkWith  \
# Academic researcher                                                 0.301956
# Blockchain                                                          0.329493
# Cloud infrastructure engineer                                       0.208404
# Data or business analyst                                            0.272102
# Data scientist or machine learning specialist                       0.264019
#
#                                                 WorkExp  DevType
# Academic researcher                            0.539313      0.0
# Blockchain                                     0.425499      0.0
# Cloud infrastructure engineer                  0.309483      0.0
# Data or business analyst                       0.404561      0.0
# Data scientist or machine learning specialist  0.417348      0.0
#
# [5 rows x 29 columns]

# %% [markdown]
# ### TopTechnologies/tools developers are currently using and what they want to use.

# %%
#Calling the function to obtain the possible(unique) answers for the necessary columns

df_clean['LanguageHaveWorkedWith']= split_multiple_answers('LanguageHaveWorkedWith')
df_clean['LanguageWantToWorkWith']=split_multiple_answers('LanguageWantToWorkWith')
df_clean['DatabaseHaveWorkedWith']=split_multiple_answers('DatabaseHaveWorkedWith')
df_clean['DatabaseWantToWorkWith']=split_multiple_answers('DatabaseWantToWorkWith')
df_clean['PlatformHaveWorkedWith']=split_multiple_answers('PlatformHaveWorkedWith')
df_clean['PlatformWantToWorkWith']=split_multiple_answers('PlatformWantToWorkWith')
df_clean['WebframeHaveWorkedWith']=split_multiple_answers('WebframeHaveWorkedWith')
df_clean['WebframeWantToWorkWith']=split_multiple_answers('WebframeWantToWorkWith')
# Out:
# C:\Users\jobao\AppData\Local\Temp/ipykernel_16584/3733984865.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].str.split(';')

# %% [markdown]
# #### Programming, scripting, and markup languages

# %%
'''

Using Pandas melt function to convert list-like column elements to separate rows 

1. Split DevType column list values (columns with individual list values are created).

2. Merge the new columns with the rest of the data set.

3. Drop the old names list column and then transform the new columns into separate rows using the melt function.

4. Additional column ‘variable’ containing the ids of the numeric columns is seen. This column is dropped and empty values are removed.

'''



def clean_and_plot(col1,col2,role):

    df1 = df_clean[col1].apply(pd.Series) \
       .merge(df_clean, right_index = True, left_index = True) \
       .drop([col1], axis = 1) \
       .melt(id_vars = df_new.loc[:,df_new.columns!=col1], value_name = col1)\
       .dropna(subset=[col1])\
       .drop("variable", axis=1) 

    f = df1.groupby(['DevType'])[col1].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col1])[df_clean['DevType'] ==role]).shape[0]
    
    df2 = df_clean[col2].apply(pd.Series) \
       .merge(df_clean, right_index = True, left_index = True) \
       .drop([col2], axis = 1) \
       .melt(id_vars = df_new.loc[:,df_new.columns!=col2], value_name = col2)\
       .dropna(subset=[col2])\
       .drop("variable", axis=1) 

    g = df2.groupby(['DevType'])[col2].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col2])[df_clean['DevType'] ==role]).shape[0]    
    
    fig, axs = plt.subplots(1,2,figsize=(10,5))
    
    f.T[role].sort_values().tail(5).plot(kind='barh', ax=axs[0],color=['orange', 'red', 'green', 'blue', 'purple'],xlabel='')
    axs[0].set_title(col1, fontsize='medium')
    #axs[0].plot(f.T[role].sort_values(ascending=False).head(5), color='blue')    

    g.T[role].sort_values().tail(5).plot(kind='barh', ax=axs[1],color=['orange', 'red', 'green', 'blue', 'purple'],xlabel='')
    axs[1].set_title(col2, fontsize='medium')

    #axs[1].plot(g.T[role].sort_values(ascending=False).head(5), color='green') 


    for c in axs[0].containers:
    # set the bar label
     axs[0].bar_label(c, fmt="%.1f%%",fontweight ='bold', label_type='center',color='white')
    for c in axs[1].containers:
    # set the bar label
     axs[1].bar_label(c, fmt='%.1f%%',fontweight ='bold', label_type='center',color='white')
        

    #axs[1].set_xlabel(col2,fontweight ='bold')
    #axs.set_title(role,fontsize='large', loc='center')
    fig.suptitle(f'Current job: {role}',fontweight ='bold')
    fig.tight_layout()
    plt.show()
#clean_and_plot('LanguageHaveWorkedWith','LanguageWantToWorkWith','Developer, back-end')

# %%
g.T['Developer, front-end']
# Out:
# DatabaseHaveWorkedWith
# Cassandra                      1.389508
# Cloud Firestore                9.295586
# CouchDB                        1.486105
# Couchbase                      0.802497
# DynamoDB                       6.858374
# Elasticsearch                  9.667112
# Firebase Realtime Database    11.086343
# IBM DB2                        1.411800
# MariaDB                       19.319364
# Microsoft SQL Server          26.259474
# MongoDB                       30.115916
# MySQL                         45.883489
# Neo4j                          1.463813
# Oracle                         9.511071
# PostgreSQL                    38.044286
# Redis                         19.772626
# SQLite                        28.146827
# Name: Developer, front-end, dtype: float64

# %%
g.T['Developer, front-end'].sort_values().tail(5).plot(kind='barh',xlabel='')
plt.show()

# %%
col1='DatabaseWantToWorkWith'
role='Developer, front-end'
df1 = df_clean[col1].apply(pd.Series) \
       .merge(df_clean, right_index = True, left_index = True) \
       .drop([col1], axis = 1) \
       .melt(id_vars = df_new.loc[:,df_new.columns!=col1], value_name = col1)\
       .dropna(subset=[col1])\
       .drop("variable", axis=1) 

f = df1.groupby(['DevType'])[col1].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col1])[df_clean['DevType'] ==role]).shape[0]
print(f.T[role].sort_values().tail(5))


col2='DatabaseHaveWorkedWith'
role='Developer, front-end'
df2 = df_clean[col2].apply(pd.Series) \
       .merge(df_clean, right_index = True, left_index = True) \
       .drop([col2], axis = 1) \
       .melt(id_vars = df_new.loc[:,df_new.columns!=col2], value_name = col2)\
       .dropna(subset=[col1])\
       .drop("variable", axis=1) 

g = df2.groupby(['DevType'])[col2].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col2])[df_clean['DevType'] ==role]).shape[0]
print(g.T[role].sort_values().tail(5))
# Out:
# C:\Users\jobao\AppData\Local\Temp/ipykernel_16584/3849792075.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   f = df1.groupby(['DevType'])[col1].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col1])[df_clean['DevType'] ==role]).shape[0]
# DatabaseWantToWorkWith
# SQLite        27.276629
# Redis         31.842760
# MySQL         36.314479
# MongoDB       39.018110
# PostgreSQL    48.236203
# Name: Developer, front-end, dtype: float64
# DatabaseHaveWorkedWith
# Microsoft SQL Server    26.259474
# SQLite                  28.146827
# MongoDB                 30.115916
# PostgreSQL              38.044286
# MySQL                   45.883489
# Name: Developer, front-end, dtype: float64
# C:\Users\jobao\AppData\Local\Temp/ipykernel_16584/3849792075.py:23: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   g = df2.groupby(['DevType'])[col2].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col2])[df_clean['DevType'] ==role]).shape[0]

# %%
clean_and_plot('LanguageHaveWorkedWith','LanguageWantToWorkWith','Developer, front-end')
# Out:
# C:\Users\jobao\AppData\Local\Temp/ipykernel_16584/2469657391.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   f = df1.groupby(['DevType'])[col1].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col1])[df_clean['DevType'] ==role]).shape[0]
# C:\Users\jobao\AppData\Local\Temp/ipykernel_16584/2469657391.py:35: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   g = df2.groupby(['DevType'])[col2].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col2])[df_clean['DevType'] ==role]).shape[0]

# %%
df_clean.shape[0]
# Out:
# 164790

# %% [markdown]
# ### Insights- programming, scripting, and markup languages
# #### SQL and Python remain the two top languages for Data or business analyst and Data scientist or machine learning specialist.
# #### Over 70% in these 2 categories want to continue or start working with Python next year. Over 20% worked with JavaScript and HTML/CSS, this is most likely because these tools are used for web development blahblah.
#
# #### SQL, JavaScript tops the list of most worked with languages for Back-end developers, in the future, Python and SQL are the two top languages these set of developers want to work with / continue working with.
#
# #### JavaScript also remains the top languages Front-end developers and full stack developers want to stick with. HTML/CSS appears second on the list of languages these developers worked with in the past year but is pushed down to 3rd place by TypeScript.
#
#
# #### For our DevOps specialists, Python and Bash/Shell appear on both lists (HaveWorkedWith  & WantToWorkWith). Go appears 3 on the list of WantToWork With.
#
# #### HTML/CSS, JavaScript, Python are still the most wanted language to work with for designers. 20% have worked with PHP over the past years.
#
# #### C, C++, Python and Bash/Shell are the top tools Developer, embedded applications or devices have worked with and want to continue/start working with. Rust overtakes Bash/Shell in the top 4 WantToWorkWith languages.

# %%
all_roles=['Data or business analyst',
'Data scientist or machine learning specialist',
'Developer, back-end',
'Developer, front-end',
'Developer, full-stack',
'DevOps specialist',
'Designer',
'Developer, embedded applications or devices']
           
           
for role in all_roles:
    clean_and_plot('LanguageHaveWorkedWith','LanguageWantToWorkWith',role)
# Out:
# C:\Users\jobao\AppData\Local\Temp/ipykernel_9600/3045286724.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   f = df1.groupby(['DevType'])[col1].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col1])[df_clean['DevType'] ==role]).shape[0]
# C:\Users\jobao\AppData\Local\Temp/ipykernel_9600/3045286724.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   g = df2.groupby(['DevType'])[col2].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col2])[df_clean['DevType'] ==role]).shape[0]

# %% [markdown]
# ### Insights- Cloud platforms
# ##### AWS remains the most used and wanted cloud platform for Data or business analyst, Data scientist or machine learning specialist, Developer, back-end, Developer, front-end, Developer, full-stack,'DevOps specialist, Developer, embedded applications or devices. And Google Cloud is the most used and wanted cloud platform for Designers.

# %%
for role in all_roles:
    clean_and_plot('PlatformHaveWorkedWith','PlatformWantToWorkWith',role)
# Out:
# C:\Users\jobao\AppData\Local\Temp/ipykernel_10676/553593740.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   f=df1.groupby(['DevType'])[col1].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col1])[df_clean['DevType'] ==role]).shape[0]
# C:\Users\jobao\AppData\Local\Temp/ipykernel_10676/553593740.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   g=df2.groupby(['DevType'])[col2].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col2])[df_clean['DevType'] ==role]).shape[0]

# %% [markdown]
# ### Databases environments
#
# ##### PostgreSQL tops the chart for all the roles except Developer, embedded applications or devices

# %%
for role in all_roles:
    clean_and_plot('DatabaseHaveWorkedWith','DatabaseWantToWorkWith',role)
# Out:
# C:\Users\jobao\AppData\Local\Temp/ipykernel_9600/3045286724.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   f = df1.groupby(['DevType'])[col1].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col1])[df_clean['DevType'] ==role]).shape[0]
# C:\Users\jobao\AppData\Local\Temp/ipykernel_9600/3045286724.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   g = df2.groupby(['DevType'])[col2].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col2])[df_clean['DevType'] ==role]).shape[0]

# %%
#test
all_roles=['Data or business analyst',
'Data scientist or machine learning specialist',
'Developer, back-end',
'Developer, front-end',
'Developer, full-stack',
'DevOps specialist',
'Designer',
'Developer, embedded applications or devices']
for role in all_roles:
    clean_and_plot('DatabaseHaveWorkedWith','DatabaseWantToWorkWith',role)
# Out:
# C:\Users\jobao\AppData\Local\Temp/ipykernel_16584/2469657391.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   f = df1.groupby(['DevType'])[col1].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col1])[df_clean['DevType'] ==role]).shape[0]
# C:\Users\jobao\AppData\Local\Temp/ipykernel_16584/2469657391.py:35: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   g = df2.groupby(['DevType'])[col2].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col2])[df_clean['DevType'] ==role]).shape[0]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16584/605699809.py in <module>
#       9 'Developer, embedded applications or devices']
#      10 for role in all_roles:
# ---> 11     clean_and_plot('DatabaseHaveWorkedWith','DatabaseWantToWorkWith',role)
#
# ~\AppData\Local\Temp/ipykernel_16584/2469657391.py in clean_and_plot(col1, col2, role)
#      17 def clean_and_plot(col1,col2,role):
#      18
# ---> 19     df1 = df_clean[col1].apply(pd.Series) \
#      20        .merge(df_clean, right_index = True, left_index = True) \
#      21        .drop([col1], axis = 1) \
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1105             # GH 25959 use pd.array instead of tolist
#    1106             # so extension arrays can be used
# -> 1107             return obj._constructor_expanddim(pd_array(mapped), index=obj.index)
#    1108         else:
#    1109             return obj._constructor(mapped, index=obj.index).__finalize__(
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     692                         # ndarray], Index, Series], Sequence[Any]]"
#     693                         columns = ensure_index(columns)  # type: ignore[arg-type]
# --> 694                     arrays, columns, index = nested_data_to_arrays(
#     695                         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     696                         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in nested_data_to_arrays(data, columns, index, dtype)
#     481         columns = ensure_index(data[0]._fields)
#     482
# --> 483     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     484     columns = ensure_index(columns)
#     485
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in to_arrays(data, columns, dtype)
#     799         arr, columns = _list_of_dict_to_arrays(data, columns)
#     800     elif isinstance(data[0], ABCSeries):
# --> 801         arr, columns = _list_of_series_to_arrays(data, columns)
#     802     else:
#     803         # last ditch effort
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in _list_of_series_to_arrays(data, columns)
#     842             indexer = indexer_cache[id(index)]
#     843         else:
# --> 844             indexer = indexer_cache[id(index)] = index.get_indexer(columns)
#     845
#     846         values = extract_array(s, extract_numpy=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    3484             )
#    3485
# -> 3486         return self._get_indexer(target, method, limit, tolerance)
#    3487
#    3488     def _get_indexer(
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\range.py in _get_indexer(self, target, method, limit, tolerance)
#     417         valid = (locs % step == 0) & (locs >= 0) & (target_array < stop)
#     418         locs[~valid] = -1
# --> 419         locs[valid] = locs[valid] / step
#     420
#     421         if step != self.step:
#
# KeyboardInterrupt:

# %%
df_lang.groupby(['DevType'])['LanguageHaveWorkedWith'].value_counts()
# Out:
# DevType               LanguageHaveWorkedWith
# Academic researcher   Python                    396
#                       C++                       201
#                       Bash/Shell                184
#                       C                         165
#                       R                         145
#                                                ...
# System administrator  Groovy                      1
#                       LISP                        1
#                       Objective-C                 1
#                       Scala                       1
#                       Solidity                    1
# Name: LanguageHaveWorkedWith, Length: 1153, dtype: int64

# %%
#Unique_current_languages
dd=df_clean['LanguageHaveWorkedWith'].value_counts().reset_index()
dd.rename(columns={ 'LanguageHaveWorkedWith': 'count'}, inplace=True)

dd
# Out:
#                                                    index  count
# 0                         HTML/CSS;JavaScript;TypeScript   2148
# 1                            HTML/CSS;JavaScript;PHP;SQL   1843
# 2                  C#;HTML/CSS;JavaScript;SQL;TypeScript   1451
# 3                             C#;HTML/CSS;JavaScript;SQL   1384
# 4                                                 Python   1279
# ...                                                  ...    ...
# 21519  Bash/Shell;Dart;Go;HTML/CSS;JavaScript;Python;...      1
# 21520      C;C++;JavaScript;MATLAB;Python;SQL;TypeScript      1
# 21521                     Bash/Shell;C;C++;Go;Lua;Python      1
# 21522                             Go;Perl;PHP;Python;SQL      1
# 21523                C++;Dart;Java;JavaScript;Python;SQL      1
#
# [21524 rows x 2 columns]

# %%
def total_count(df, col1, col2, look_for):
    '''
    INPUT:
    df - the pandas dataframe you want to search
    col1 - the column name you want to look through
    col2 - the column you want to count values from
    look_for - a list of strings you want to search for in each row of df[col]

    OUTPUT:
    new_df - a dataframe of each look_for with the count of how often it shows up
    '''
    new_df = defaultdict(int)
    #loop through list of ed types
    for val in look_for:
        #loop through rows
        for idx in range(df.shape[0]):
            #if the ed type is in the row add 1
            if val in df[col1][idx]:
                new_df[val] += int(df[col2][idx])
    new_df = pd.DataFrame(pd.Series(new_df)).reset_index()
    new_df.columns = [col1, col2]
    new_df.sort_values('count', ascending=False, inplace=True)
    return new_df

# %%
gg=total_count(dd,'index','count',Unique_current_languages)

# %%
gg
# Out:
#           index   count
# 20            C  130671
# 33         Java  129270
# 14   JavaScript  116378
# 25     HTML/CSS   98440
# 10          SQL   96460
# 3        Python   79096
# 11   TypeScript   65287
# 26   Bash/Shell   56496
# 34           C#   53657
# 2           PHP   43068
# 1           C++   38014
# 32            R   31936
# 29   PowerShell   26404
# 31           Go   22072
# 21       Kotlin   16781
# 17         Rust   15706
# 15         Dart   13100
# 41         Ruby   12095
# 36          VBA   10508
# 13     Assembly   10192
# 24        Swift   10092
# 35       Delphi    9409
# 30          Lua    7654
# 7        MATLAB    7627
# 8        Groovy    7183
# 19         Perl    6185
# 16  Objective-C    5943
# 9         Scala    5420
# 0        Elixir    4619
# 27      Haskell    4069
# 40     Solidity    3917
# 12      Clojure    3278
# 18        Julia    3172
# 22         LISP    3044
# 23           F#    2698
# 4        Erlang    2625
# 28      Fortran    2537
# 37          APL    2221
# 39        COBOL    2141
# 6           SAS    1925
# 5       Crystal    1793
# 38        OCaml    1571

# %%
f.T[role]/(df_clean[df_clean['DevType'] == role]).shape[0]
# Out:
# LanguageHaveWorkedWith
# APL            0.000008
# Assembly       0.001123
# Bash/Shell     0.002779
# C              0.004161
# C#             0.000970
# C++            0.003725
# COBOL          0.000024
# Clojure        0.000008
# Crystal        0.000016
# Dart           0.000040
# Delphi         0.000057
# Elixir         0.000016
# Erlang         0.000032
# F#             0.000008
# Fortran        0.000032
# Go             0.000355
# Groovy         0.000170
# HTML/CSS       0.001002
# Haskell        0.000105
# Java           0.000816
# JavaScript     0.001204
# Julia          0.000057
# Kotlin         0.000218
# LISP           0.000105
# Lua            0.000315
# MATLAB         0.000695
# OCaml          0.000008
# Objective-C    0.000113
# PHP            0.000307
# Perl           0.000210
# PowerShell     0.000493
# Python         0.003571
# R              0.000081
# Ruby           0.000178
# Rust           0.000929
# SAS            0.000000
# SQL            0.000776
# Scala          0.000040
# Solidity       0.000000
# Swift          0.000121
# TypeScript     0.000420
# VBA            0.000202
# Name: Developer, embedded applications or devices, dtype: float64

# %% [markdown]
# # Learn how to code

# %% [markdown]
# Questions in this section are:
# ##### How did you learn to code?(LearnCode)
# ##### What online resources do you use to learn to code?(LearnCodeOnline)
# ##### What online courses or certifications do you use to learn to code?(LearnCodeCoursesCert)

# %%
df_clean[['LearnCode', 'LearnCodeOnline', 'LearnCodeCoursesCert']]
# Out:
#                                                  LearnCode  \
# 0        Books / Physical media;Friend or family member...
# 1        Books / Physical media;School (i.e., Universit...
# 2        Other online resources (e.g., videos, blogs, f...
# 3                          Online Courses or Certification
# 4                      On the job training;Coding Bootcamp
# ...                                                    ...
# 1764589  Books / Physical media;Friend or family member...
# 1768822  Books / Physical media;Friend or family member...
# 1773947                             Books / Physical media
# 1774051  Books / Physical media;Friend or family member...
# 1775044  Books / Physical media;Online Courses or Certi...
#
#                                            LearnCodeOnline  \
# 0        Technical documentation;Blogs;Programming Game...
# 1                                                      NaN
# 2        Technical documentation;Blogs;Stack Overflow;O...
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1764589  Technical documentation;Blogs;Programming Game...
# 1768822  Technical documentation;Blogs;Programming Game...
# 1773947                                                NaN
# 1774051  Technical documentation;Blogs;Programming Game...
# 1775044                                                NaN
#
#                                       LearnCodeCoursesCert
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                           Coursera;Udemy
# 4                                                      NaN
# ...                                                    ...
# 1764589  Coursera;Udemy;Codecademy;Pluralsight;edX;Udac...
# 1768822  Coursera;Udemy;Codecademy;Pluralsight;edX;Udac...
# 1773947                                                NaN
# 1774051  Coursera;Udemy;Codecademy;Pluralsight;edX;Udac...
# 1775044                                   Codecademy;Other
#
# [164790 rows x 3 columns]

# %%
#Calling the function to obtain the possible(unique) answers for the necessary columns

df_clean['LearnCode']= split_multiple_answers('LearnCode')
df_clean['LearnCodeOnline']=split_multiple_answers('LearnCodeOnline')
df_clean['LearnCodeCoursesCert']=split_multiple_answers('LearnCodeCoursesCert')
# Out:
# C:\Users\jobao\AppData\Local\Temp/ipykernel_6896/164317998.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].str.split(';')

# %%
(df_clean.dropna(subset=['LearnCode'])[df_clean['DevType'] =='Developer, back-end']).shape[0]
(df_cleandf_clean[df_clean['DevType'] =='Developer, back-end']).shape[0]
# Out:
# C:\Users\jobao\AppData\Local\Temp/ipykernel_10676/4125361866.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   (df_clean.dropna(subset=['LearnCode'])[df_clean['DevType'] =='Developer, back-end']).shape[0]
# 10478

# %%
col1 = 'LearnCode'
col2 = 'LearnCodeOnline'
col3 = 'LearnCodeCoursesCert'
role='Developer, back-end'
df3=df_clean[col3].apply(pd.Series) \
       .merge(df_clean, right_index = True, left_index = True) \
       .drop([col3], axis = 1) \
       .melt(id_vars = df_new.loc[:,df_new.columns!=col3], value_name = col3)\
       .dropna(subset=[col3])\
       .drop("variable", axis=1) 

h=df3.groupby(['DevType'])[col3].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col3])[df_clean['DevType'] ==role]).shape[0]  
    
print(h.T[role].sort_values().tail(5))

df2=df_clean[col2].apply(pd.Series) \
       .merge(df_clean, right_index = True, left_index = True) \
       .drop([col2], axis = 1) \
       .melt(id_vars = df_new.loc[:,df_new.columns!=col2], value_name = col2)\
       .dropna(subset=[col2])\
       .drop("variable", axis=1) 

g=df2.groupby(['DevType'])[col2].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col2])[df_clean['DevType'] ==role]).shape[0]  
    
print(g.T[role].sort_values().tail(5))

df1=df_clean[col1].apply(pd.Series) \
       .merge(df_clean, right_index = True, left_index = True) \
       .drop([col1], axis = 1) \
       .melt(id_vars = df_new.loc[:,df_new.columns!=col1], value_name = col1)\
       .dropna(subset=[col1])\
       .drop("variable", axis=1) 

f=df1.groupby(['DevType'])[col1].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col1])[df_clean['DevType'] ==role]).shape[0]  
    
print(f.T[role].sort_values().tail(5))
# Out:
# C:\Users\jobao\AppData\Local\Temp/ipykernel_6896/2153574582.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   h=df3.groupby(['DevType'])[col3].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col3])[df_clean['DevType'] ==role]).shape[0]
# LearnCodeCoursesCert
# Other          19.035597
# Codecademy     21.004797
# Pluralsight    26.331734
# Coursera       38.424640
# Udemy          68.038374
# Name: Developer, back-end, dtype: float64
# C:\Users\jobao\AppData\Local\Temp/ipykernel_6896/2153574582.py:23: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   g=df2.groupby(['DevType'])[col2].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col2])[df_clean['DevType'] ==role]).shape[0]
# LearnCodeOnline
# How-to videos              52.512489
# Written Tutorials          58.565971
# Blogs                      78.225096
# Stack Overflow             84.263885
# Technical documentation    90.669997
# Name: Developer, back-end, dtype: float64
# LearnCode
# Online Courses or Certification                        42.908952
# On the job training                                    44.378698
# Books / Physical media                                 60.326398
# Other online resources (e.g., videos, blogs, forum)    65.031495
# School (i.e., University, College, etc)                68.161863
# Name: Developer, back-end, dtype: float64
# C:\Users\jobao\AppData\Local\Temp/ipykernel_6896/2153574582.py:34: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   f=df1.groupby(['DevType'])[col1].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col1])[df_clean['DevType'] ==role]).shape[0]

# %% [markdown]
# ##### The majority of developers, as we can see, learn to code from online resources. It seems to be the trend to educate yourself outside of the university system and it is very important to take this very seriously as a beginner. We see that developers frequently use Udemy and Coursera for online courses/certifications, technical documentation to properly learn a tool/ framework and Stack overflow for quick tips and solutions to programming problems (online resources).
# ##### In general, online courses/certifications are a good place to start. As you learn, supplement your learning with StackOverflow and technical documentation.

# %%
# Without role aggregation


def clean_and_plot():
    col1 = 'LearnCode'
    col2 = 'LearnCodeOnline'
    col3 = 'LearnCodeCoursesCert'

    df1=df_clean[col1].apply(pd.Series) \
       .merge(df_clean, right_index = True, left_index = True) \
       .drop([col1], axis = 1) \
       .melt(id_vars = df_new.loc[:,df_new.columns!=col1], value_name = col1)\
       .dropna(subset=[col1])\
       .drop("variable", axis=1) 

    f=df1[col1].value_counts()/(df_clean.dropna(subset=[col1])).shape[0]*100
    
    df2=df_clean[col2].apply(pd.Series) \
       .merge(df_clean, right_index = True, left_index = True) \
       .drop([col2], axis = 1) \
       .melt(id_vars = df_new.loc[:,df_new.columns!=col2], value_name = col2)\
       .dropna(subset=[col2])\
       .drop("variable", axis=1) 

    #g=df2.groupby(['DevType'])[col2].value_counts(normalize=True).mul(100).unstack().fillna(0)  
    g=df2[col2].value_counts()/(df_clean.dropna(subset=[col2])).shape[0]*100

    
    df3=df_clean[col3].apply(pd.Series) \
       .merge(df_clean, right_index = True, left_index = True) \
       .drop([col3], axis = 1) \
       .melt(id_vars = df_new.loc[:,df_new.columns!=col3], value_name = col3)\
       .dropna(subset=[col3])\
       .drop("variable", axis=1) 

    h=df3[col3].value_counts()/(df_clean.dropna(subset=[col3])).shape[0]*100
    fig, axs = plt.subplots(3,figsize=(10, 8))
    #plt.figure(figsize=(20,20))
    
    f.sort_values().tail(5).plot(kind='barh', ax=axs[0],color=['orange', 'red', 'green', 'blue', 'purple'],xlabel='')
    axs[0].set_title('Learning how to code', fontsize='medium')

    #axs[0].set_ylabel(col1,fontweight ='bold',fontsize='large')

    g.sort_values().tail(5).plot(kind='barh', ax=axs[1],color=['orange', 'red', 'green', 'blue', 'purple'],xlabel='')
   # axs[1].set_ylabel(col2,fontweight ='bold',fontsize='medium')
    axs[1].set_title('Online resources to learn how to code', fontsize='medium')
    
    h.sort_values().tail(5).plot(kind='barh', ax=axs[2],color=['orange', 'red', 'green', 'blue', 'olive'],xlabel='')
    #axs[2].set_ylabel(col3,fontweight ='bold',fontsize='medium')
    axs[2].set_title('Online course platforms to learn how to code', fontsize='medium')


    for c in axs[0].containers:
    # set the bar label
        axs[0].bar_label(c, fmt="%.1f%%", label_type='center',fontweight ='bold',color='white')
    for c in axs[1].containers:
    # set the bar label
        axs[1].bar_label(c, fmt='%.1f%%', label_type='center',fontweight ='bold',color='white')
    for c in axs[2].containers:
    # set the bar label
        axs[2].bar_label(c, fmt='%.1f%%', label_type='center',fontweight ='bold',color='white')
    fig.suptitle(f'How developers are learning to code',fontweight ='bold',fontsize='large',ha='left')
    fig.tight_layout()
   


    plt.show()
clean_and_plot()

# %%
#Calling the function to obtain the possible(unique) answers for the necessary columns

df['LearnCode']= split_multiple_answers('LearnCode')
df['LearnCodeOnline']=split_multiple_answers('LearnCodeOnline')
df['LearnCodeCoursesCert']=split_multiple_answers('LearnCodeCoursesCert')

col1='LearnCodeCoursesCert'
df1=df[col1].apply(pd.Series) \
       .merge(df, right_index = True, left_index = True) \
       .drop([col1], axis = 1) \
       .melt(id_vars = df.loc[:,df.columns!=col1], value_name = col1)\
       .dropna(subset=[col1])\
       .drop("variable", axis=1) 

#f=df1.groupby(['DevType'])[col1].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col1])).shape[0]
f=df1[col1].value_counts()/(df.dropna(subset=[col1])).shape[0]*100
f
# Out:
# C:\Users\jobao\AppData\Local\Temp/ipykernel_6896/164317998.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].str.split(';')
# Udemy          68.457187
# Coursera       35.474937
# Codecademy     25.203823
# Pluralsight    24.907353
# Other          21.014238
# edX            15.268188
# Udacity        14.207139
# Skillsoft       1.950458
# Name: LearnCodeCoursesCert, dtype: float64

# %%
(df.dropna(subset=['LearnCode'])).shape[0]
# Out:
# 71580

# %%
def clean_and_plot(role):
    col1 = 'LearnCode'
    col2 = 'LearnCodeOnline'
    col3 = 'LearnCodeCoursesCert'

    df1=df_clean[col1].apply(pd.Series) \
       .merge(df_clean, right_index = True, left_index = True) \
       .drop([col1], axis = 1) \
       .melt(id_vars = df_new.loc[:,df_new.columns!=col1], value_name = col1)\
       .dropna(subset=[col1])\
       .drop("variable", axis=1) 

    f=df1.groupby(['DevType'])[col1].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col1])[df_clean['DevType'] ==role]).shape[0]
    
    df2=df_clean[col2].apply(pd.Series) \
       .merge(df_clean, right_index = True, left_index = True) \
       .drop([col2], axis = 1) \
       .melt(id_vars = df_new.loc[:,df_new.columns!=col2], value_name = col2)\
       .dropna(subset=[col2])\
       .drop("variable", axis=1) 

    #g=df2.groupby(['DevType'])[col2].value_counts(normalize=True).mul(100).unstack().fillna(0)  
    g=df2.groupby(['DevType'])[col2].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col2])[df_clean['DevType'] ==role]).shape[0]

    
    df3=df_clean[col3].apply(pd.Series) \
       .merge(df_clean, right_index = True, left_index = True) \
       .drop([col3], axis = 1) \
       .melt(id_vars = df_new.loc[:,df_new.columns!=col3], value_name = col3)\
       .dropna(subset=[col3])\
       .drop("variable", axis=1) 

    h=df3.groupby(['DevType'])[col3].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col3])[df_clean['DevType'] ==role]).shape[0]  
    
    fig, axs = plt.subplots(3,figsize=(10, 8))
    #plt.figure(figsize=(20,20))
    
    f.T[role].sort_values().tail(5).plot(kind='barh', ax=axs[0],color=['orange', 'red', 'green', 'blue', 'purple'],xlabel='')
    axs[0].set_title('Learning how to code', fontsize='medium')

    #axs[0].set_ylabel(col1,fontweight ='bold',fontsize='large')

    g.T[role].sort_values().tail(5).plot(kind='barh', ax=axs[1],color=['orange', 'red', 'green', 'blue', 'purple'],xlabel='')
   # axs[1].set_ylabel(col2,fontweight ='bold',fontsize='medium')
    axs[1].set_title('Online resources to learn how to code', fontsize='medium')
    
    h.T[role].sort_values().tail(5).plot(kind='barh', ax=axs[2],color=['orange', 'red', 'green', 'blue', 'olive'],xlabel='')
    #axs[2].set_ylabel(col3,fontweight ='bold',fontsize='medium')
    axs[2].set_title('Online course platforms to learn how to code', fontsize='medium')


    for c in axs[0].containers:
    # set the bar label
        axs[0].bar_label(c, fmt="%.1f%%", label_type='center',fontweight ='bold',color='white')
    for c in axs[1].containers:
    # set the bar label
        axs[1].bar_label(c, fmt='%.1f%%', label_type='center',fontweight ='bold',color='white')
    for c in axs[2].containers:
    # set the bar label
        axs[2].bar_label(c, fmt='%.1f%%', label_type='center',fontweight ='bold',color='white')
    fig.suptitle(f'How developers are learning to code - Current job:{role}',fontweight ='bold',fontsize='large',ha='left')
    fig.tight_layout()
    fig.supylabel('Learning how to code')


    plt.show()
clean_and_plot('Data or business analyst')
# Out:
# C:\Users\jobao\AppData\Local\Temp/ipykernel_9600/3223804575.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   f=df1.groupby(['DevType'])[col1].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col1])[df_clean['DevType'] ==role]).shape[0]
# C:\Users\jobao\AppData\Local\Temp/ipykernel_9600/3223804575.py:23: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   g=df2.groupby(['DevType'])[col2].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col2])[df_clean['DevType'] ==role]).shape[0]
# C:\Users\jobao\AppData\Local\Temp/ipykernel_9600/3223804575.py:33: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   h=df3.groupby(['DevType'])[col3].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col3])[df_clean['DevType'] ==role]).shape[0]

# %%
def clean_and_plot(role):
    col1 = 'LearnCode'
    col2 = 'LearnCodeOnline'
    col3 = 'LearnCodeCoursesCert'

    df1=df_clean[col1].apply(pd.Series) \
       .merge(df_clean, right_index = True, left_index = True) \
       .drop([col1], axis = 1) \
       .melt(id_vars = df_new.loc[:,df_new.columns!=col1], value_name = col1)\
       .dropna(subset=[col1])\
       .drop("variable", axis=1) 

    f=df1.groupby(['DevType'])[col1].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col1])[df_clean['DevType'] ==role]).shape[0]
    
    df2=df_clean[col2].apply(pd.Series) \
       .merge(df_clean, right_index = True, left_index = True) \
       .drop([col2], axis = 1) \
       .melt(id_vars = df_new.loc[:,df_new.columns!=col2], value_name = col2)\
       .dropna(subset=[col2])\
       .drop("variable", axis=1) 

    #g=df2.groupby(['DevType'])[col2].value_counts(normalize=True).mul(100).unstack().fillna(0)  
    g=df2.groupby(['DevType'])[col2].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col2])[df_clean['DevType'] ==role]).shape[0]

    
    df3=df_clean[col3].apply(pd.Series) \
       .merge(df_clean, right_index = True, left_index = True) \
       .drop([col3], axis = 1) \
       .melt(id_vars = df_new.loc[:,df_new.columns!=col3], value_name = col3)\
       .dropna(subset=[col3])\
       .drop("variable", axis=1) 

    h=df3.groupby(['DevType'])[col3].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col3])[df_clean['DevType'] ==role]).shape[0]  
    
    fig, axs = plt.subplots(3,figsize=(10, 8))
    #plt.figure(figsize=(20,20))
    
    f.T[role].sort_values().tail(5).plot(kind='barh', ax=axs[0],color=['orange', 'red', 'green', 'blue', 'purple'],xlabel='')
    axs[0].set_title('Learning how to code', fontsize='medium')

    #axs[0].set_ylabel(col1,fontweight ='bold',fontsize='large')

    g.T[role].sort_values().tail(5).plot(kind='barh', ax=axs[1],color=['orange', 'red', 'green', 'blue', 'purple'],xlabel='')
   # axs[1].set_ylabel(col2,fontweight ='bold',fontsize='medium')
    axs[1].set_title('Online resources to learn how to code', fontsize='medium')
    
    h.T[role].sort_values().tail(5).plot(kind='barh', ax=axs[2],color=['orange', 'red', 'green', 'blue', 'olive'],xlabel='')
    #axs[2].set_ylabel(col3,fontweight ='bold',fontsize='medium')
    axs[2].set_title('Online course platforms to learn how to code', fontsize='medium')


    for c in axs[0].containers:
    # set the bar label
        axs[0].bar_label(c, fmt="%.1f%%", label_type='center',fontweight ='bold',color='white')
    for c in axs[1].containers:
    # set the bar label
        axs[1].bar_label(c, fmt='%.1f%%', label_type='center',fontweight ='bold',color='white')
    for c in axs[2].containers:
    # set the bar label
        axs[2].bar_label(c, fmt='%.1f%%', label_type='center',fontweight ='bold',color='white')
    fig.suptitle(f'How developers are learning to code - Current job:{role}',fontweight ='bold',fontsize='large',ha='left')
    fig.tight_layout()
    fig.supylabel('Learning how to code')


    plt.show()
clean_and_plot('Developer, back-end')
# Out:
# C:\Users\jobao\AppData\Local\Temp/ipykernel_1660/1462461740.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   f=df1.groupby(['DevType'])[col1].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col1])[df_clean['DevType'] ==role]).shape[0]
# C:\Users\jobao\AppData\Local\Temp/ipykernel_1660/1462461740.py:23: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   g=df2.groupby(['DevType'])[col2].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col2])[df_clean['DevType'] ==role]).shape[0]
# C:\Users\jobao\AppData\Local\Temp/ipykernel_1660/1462461740.py:33: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   h=df3.groupby(['DevType'])[col3].value_counts().mul(100).unstack().fillna(0)/(df_clean.dropna(subset=[col3])[df_clean['DevType'] ==role]).shape[0]

# %% [markdown]
# ### Highest level of formal education completed

# %% [markdown]
# #### I find it really interesting (not surprising though) that people without college degrees are beginning to dominate the tech-space these days.
# #### Clearly ranking third among the most sought-after tech jobs and even challenging designers with master's degrees.

# %%
df_clean.groupby('DevType')['EdLevel'].value_counts()
#df_clean.groupby(['DevType'])['LearnCode'].value_counts()
# Out:
# DevType               EdLevel
# Academic researcher   Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       975
#                       Other doctoral degree (Ph.D., Ed.D., etc.)                                            754
#                       Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          595
#                       Some college/university study without earning a degree                                167
#                       Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     85
#                                                                                                            ...
# System administrator  Associate degree (A.A., A.S., etc.)                                                   222
#                       Other doctoral degree (Ph.D., Ed.D., etc.)                                            159
#                       Primary/elementary school                                                             103
#                       Professional degree (JD, MD, etc.)                                                    102
#                       Something else                                                                         98
# Name: EdLevel, Length: 261, dtype: int64

# %%
df_clean[df_clean['DevType']=='Designer'].shape[0]
# Out:
# 3764

# %%
#data.sort_values(['Associate degree (A.A., A.S., etc.)','Bachelor’s degree (B.A., B.S., B.Eng., etc.)','Master’s degree (M.A., M.S., M.Eng., MBA, etc.)','Other doctoral degree (Ph.D., Ed.D., etc.)','Professional degree (JD, MD, etc.)','Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)','Some college/university study without earning a degree'],ascending=False).plot(kind='bar',figsize=(10,8))
data.sort_values(rows,axis=0,ascending=False).plot(kind='bar',figsize=(10,8))
plt.legend(loc ='upper center')

# %%
df_clean.groupby(['EdLevel']).count()
# Out:
#                                                     ResponseId  MainBranch  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                       5597        5597
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)             70836       70836
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)          39078       39078
# Other doctoral degree (Ph.D., Ed.D., etc.)                6040        6040
# Primary/elementary school                                 2397        2397
# Professional degree (JD, MD, etc.)                        3298        3298
# Secondary school (e.g. American high school, Ge...       11832       11832
# Some college/university study without earning a...       23140       23140
# Something else                                            2356        2356
#
#                                                     Employment  RemoteWork  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                       5597        5367
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)             70836       68698
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)          39078       38509
# Other doctoral degree (Ph.D., Ed.D., etc.)                6040        6000
# Primary/elementary school                                 2397        2114
# Professional degree (JD, MD, etc.)                        3298        3218
# Secondary school (e.g. American high school, Ge...       11832       10872
# Some college/university study without earning a...       23140       22091
# Something else                                            2356        2188
#
#                                                     LearnCode  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                      1988
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)            28053
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)         14761
# Other doctoral degree (Ph.D., Ed.D., etc.)               2058
# Primary/elementary school                                 617
# Professional degree (JD, MD, etc.)                       1043
# Secondary school (e.g. American high school, Ge...       4102
# Some college/university study without earning a...       7780
# Something else                                            787
#
#                                                     LearnCodeOnline  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                            1432
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                  19359
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                9784
# Other doctoral degree (Ph.D., Ed.D., etc.)                     1248
# Primary/elementary school                                       460
# Professional degree (JD, MD, etc.)                              685
# Secondary school (e.g. American high school, Ge...             3258
# Some college/university study without earning a...             5941
# Something else                                                  545
#
#                                                     LearnCodeCoursesCert  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                  920
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                       12331
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                     5963
# Other doctoral degree (Ph.D., Ed.D., etc.)                           535
# Primary/elementary school                                            212
# Professional degree (JD, MD, etc.)                                   476
# Secondary school (e.g. American high school, Ge...                  1576
# Some college/university study without earning a...                  3313
# Something else                                                       296
#
#                                                     YearsCode  YearsCodePro  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                      5579          4617
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)            70638         60900
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)         38922         35460
# Other doctoral degree (Ph.D., Ed.D., etc.)               6018          5556
# Primary/elementary school                                2310          1294
# Professional degree (JD, MD, etc.)                       3284          2835
# Secondary school (e.g. American high school, Ge...      11768          7244
# Some college/university study without earning a...      23040         18073
# Something else                                           2346          1709
#
#                                                     OrgSize  ...  \
# EdLevel                                                      ...
# Associate degree (A.A., A.S., etc.)                    4576  ...
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)          60305  ...
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)       34778  ...
# Other doctoral degree (Ph.D., Ed.D., etc.)             5480  ...
# Primary/elementary school                              1308  ...
# Professional degree (JD, MD, etc.)                     2788  ...
# Secondary school (e.g. American high school, Ge...     7177  ...
# Some college/university study without earning a...    17894  ...
# Something else                                         1636  ...
#
#                                                     OpSysProfessional use  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                  5241
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                        67713
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                     37597
# Other doctoral degree (Ph.D., Ed.D., etc.)                           5847
# Primary/elementary school                                            2073
# Professional degree (JD, MD, etc.)                                   3156
# Secondary school (e.g. American high school, Ge...                  11150
# Some college/university study without earning a...                  21989
# Something else                                                       2155
#
#                                                     OpSysPersonal use  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                              5565
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                    70155
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                 38695
# Other doctoral degree (Ph.D., Ed.D., etc.)                       5981
# Primary/elementary school                                        2276
# Professional degree (JD, MD, etc.)                               3273
# Secondary school (e.g. American high school, Ge...              11753
# Some college/university study without earning a...              22941
# Something else                                                   2270
#
#                                                     VersionControlSystem  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                 5568
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                       70699
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                    38937
# Other doctoral degree (Ph.D., Ed.D., etc.)                          6026
# Primary/elementary school                                           2321
# Professional degree (JD, MD, etc.)                                  3289
# Secondary school (e.g. American high school, Ge...                 11802
# Some college/university study without earning a...                 23059
# Something else                                                      2337
#
#                                                     VCInteraction  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                          5361
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                69082
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)             37880
# Other doctoral degree (Ph.D., Ed.D., etc.)                   5714
# Primary/elementary school                                    2085
# Professional degree (JD, MD, etc.)                           3086
# Secondary school (e.g. American high school, Ge...          11303
# Some college/university study without earning a...          22297
# Something else                                               2158
#
#                                                     OfficeStackAsyncHaveWorkedWith  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                           3887
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                 50794
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                              27474
# Other doctoral degree (Ph.D., Ed.D., etc.)                                    3402
# Primary/elementary school                                                     1474
# Professional degree (JD, MD, etc.)                                            2149
# Secondary school (e.g. American high school, Ge...                            7547
# Some college/university study without earning a...                           15722
# Something else                                                                1383
#
#                                                     OfficeStackAsyncWantToWorkWith  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                           2676
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                 36123
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                              19826
# Other doctoral degree (Ph.D., Ed.D., etc.)                                    2294
# Primary/elementary school                                                     1021
# Professional degree (JD, MD, etc.)                                            1495
# Secondary school (e.g. American high school, Ge...                            5270
# Some college/university study without earning a...                           10874
# Something else                                                                 939
#
#                                                     OfficeStackSyncHaveWorkedWith  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                          5090
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                65566
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                             36420
# Other doctoral degree (Ph.D., Ed.D., etc.)                                   5663
# Primary/elementary school                                                    1646
# Professional degree (JD, MD, etc.)                                           2872
# Secondary school (e.g. American high school, Ge...                           9826
# Some college/university study without earning a...                          20506
# Something else                                                               1946
#
#                                                     OfficeStackSyncWantToWorkWith  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                          3947
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                52572
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                             29882
# Other doctoral degree (Ph.D., Ed.D., etc.)                                   4554
# Primary/elementary school                                                    1163
# Professional degree (JD, MD, etc.)                                           2294
# Secondary school (e.g. American high school, Ge...                           7198
# Some college/university study without earning a...                          15843
# Something else                                                               1385
#
#                                                     WorkExp  DevType
# EdLevel
# Associate degree (A.A., A.S., etc.)                    3369     5597
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)          45414    70836
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)       24898    39078
# Other doctoral degree (Ph.D., Ed.D., etc.)             3360     6040
# Primary/elementary school                               993     2397
# Professional degree (JD, MD, etc.)                     1837     3298
# Secondary school (e.g. American high school, Ge...     5145    11832
# Some college/university study without earning a...    13088    23140
# Something else                                         1190     2356
#
# [9 rows x 34 columns]
